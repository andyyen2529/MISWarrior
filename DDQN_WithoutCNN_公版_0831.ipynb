# %%
"""
注意事項(關於ver2)： 
一、神經網路架構：
    3層CNN(卷積神經網絡) + 2層Linear

二、狀態變數(一共37個)： 
    收盤價MA5, 收盤價MA10, 收盤價MA20, 收盤價MA60, 收盤價MA120, 收盤價MA240
    成交股數MA5, 成交股數MA10, 成交股數MA20, 成交股數MA60, 成交股數MA120, 成交股數MA240
    成交金額MA5, 成交金額MA10, 成交金額MA20, 成交金額MA60, 成交金額MA120, 成交金額MA240
    成交股數.1
    開盤價.1
    最高價.1
    最低價.1
    收盤價.1
    漲跌價差.1
    月份(one-hot，一到十二月共十二個變數)
    當前資產部位

三、reward公式：
    reward(t) = ln(Wt / Wt-1)
    
    Action  Wt                            Wt-1
    -----------------------------------------------------------------
    wait    t期agent持有的現金             t-1期agent持有的現金
    
    buy     t期收盤價 * agent持有的股數    t-1期agent持有的現金
    
    hold    t期收盤價 * agent持有的股數    t-1期收盤價 * agent持有的股數
    
    sell    t期agent持有的現金             t-n期買價 * agent持有的股數
            (t期開盤價 * agent持有的股數 
            * (1 - 交易成本比率))
            
四、調參成效的指標
    1. 訓練集最後100個episode的平均報酬率
    2. 驗證集的平均報酬率
    
五、嘗試調整方向
    1. 交易價格統一用t-1期收盤價
    2. 

"""
# 輸入相關的函式庫
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import statistics
import csv
import matplotlib.pyplot as plt
import math
from torch.autograd import Variable
from copy import deepcopy
import pandas as pd

# %%
# 可調整的超參數
TARGET_REPLACE_ITER = 5 # x；target network更新的頻率(每訓練幾次更新一次)
BATCH_SIZE_ACCOUNT_FOR_MEMORY_CAPACITY = 0.08 # 訓練抽取的批量大小為記憶體大小的多少比例(0到1之間)

LR = 0.003 # learning rate (學習率，越大代表訓練速度將會越快，但太大可能會導致模型難以收斂)
GAMMA = 0.95 # discount rate (折現率，越接近1代表DQN越重視未來的經驗)

EPSILON_MIN = 0.01 # 隨機選取行動的機率的最小值
EPSILON_DECAY = 0.995 # 隨機選取行動的機率在每次訓練一次後衰退所剩餘的比例 (該值必須介於0到1之間)

# 第一層的節點數

# 以下超參數不建議在現階段調整
EPISODES = 1000 # 訓練過程中的疊代次數(一共要玩幾輪股市交易)

EPSILON = 1.0  # 隨機(而非依據模型結果)選取行動的機率的起始值

'''
台灣50
'''
TRAIN_START_DAY = '2014/1/2' # 訓練集起始的日期
TRAIN_END_DAY = '2015/12/31' # 訓練集結束的日期

VALIDATION_START_DAY = '2016/1/4' # 驗證集起始的日期
VALIDATION_END_DAY = '2016/3/31' # 驗證集結束的日期

TEST_START_DAY = '2016/4/1' # 驗證集起始的日期
TEST_END_DAY = '2016/6/30' # 驗證集結束的日期

'''
燦坤
'''
# TRAIN_START_DAY = '2015/1/5' # 訓練集起始的日期
# TRAIN_END_DAY = '2016/12/30' # 訓練集結束的日期

# VALIDATION_START_DAY = '2017/1/3' # 驗證集起始的日期
# VALIDATION_END_DAY =  '2017/3/31'# 驗證集結束的日期

# TEST_START_DAY = '2017/4/5' # 驗證集起始的日期
# TEST_END_DAY = '2017/6/30' # 驗證集結束的日期
'''
東元
'''
# TRAIN_START_DAY = '2014/1/2' # 訓練集起始的日期
# TRAIN_END_DAY = '2015/12/31' # 訓練集結束的日期

# VALIDATION_START_DAY = '2016/1/4' # 驗證集起始的日期
# VALIDATION_END_DAY =  '2016/3/31'# 驗證集結束的日期

# TEST_START_DAY = '2016/4/1' # 驗證集起始的日期
# TEST_END_DAY = '2016/6/30' # 驗證集結束的日期

# 以下超參數目前在這邊設定並不會發揮作用，可以忽略
MEMORY_CAPACITY = 2000 # memory(記憶體)的大小
BATCH_SIZE = 20 # b；每次訓練時從memory中選取要訓練的資料的批量大小
#ENOUGH_MEMORY_TO_TRAIN = 200 # 當memory超過多少筆資料才開始訓練模型
#TRAIN_INTERVAL = 5 # k；每增加多少筆經驗(每過幾天)會再次訓練模型

'''
正常版
'''

# 以下的超參數必須根據不同的資料集(csv檔)做修改
YOUR_CSVFILE_PATH = "D:/專案/資料集/twse0050_ver10.csv" # 路徑請自己改
N_STATES = 37 # state size (= [收盤價MA5, 收盤價MA10, ... ,當前資產部位]，一共37個狀態變數)
STATE_VARIABLE_DISCRETE_START_INDEX = 33 # 資料集中離散(類別)型別的狀態變數開始的欄位的「索引(從0開始算)_」(一月) 

# 以下的超參數是目前希望特定的欄位在資料集中所在的位置，能不改就不要改
N_COLUMNS = 46 
    # 資料集一共的欄位數(前九個希望固定為「日期, 成交股數, 成交金額, 成交筆數, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差」)
OPENING_PRICE_INDEX = 4 # 資料集中「開盤價」欄位的索引
CLOSING_PRICE_INDEX = 7 # 資料集中「收盤價」欄位的索引
STATE_VARIABLE_START_INDEX = 9 # 資料集中狀態變數開始的欄位的「索引」(從0開始算)(收盤價MA5)
STATE_VARIABLE_CONTINUOUS_END_INDEX = STATE_VARIABLE_DISCRETE_START_INDEX - 1 
    # 資料集中連續型別的狀態變數結束的欄位的索引(漲跌價差.1) (目前希望離散型別的狀態變數接在類別型別的狀態變數之後)
CURRENT_POSITION_INDEX = 45 # 資料集中「當前資產部位」欄位的索引 (目前希望是位在資料集中最後一個欄位)

# 以下的超參數並非是調參的重點，能不改就不要改
N_ACTIONS = 2 # action size (= [0, 1])
TRANSACTION_COST_RATE = 0.001425 # 參考實際的手續費率
'''
簡易版
'''
# # 以下的超參數必須根據不同的資料集(csv檔)做修改
# YOUR_CSVFILE_PATH = "D:/專案/資料集/twse0050_ver11(新增成對交易欄位-變數簡易版).csv" # 路徑請自己改
# N_STATES = 8 # state size (= [收盤價MA5, 收盤價MA10, ... ,當前資產部位]，一共37個狀態變數)
# STATE_VARIABLE_DISCRETE_START_INDEX = 17 # 資料集中離散(類別)型別的狀態變數開始的欄位的「索引(從0開始算)_」(一月) 

# # 以下的超參數是目前希望特定的欄位在資料集中所在的位置，能不改就不要改
# N_COLUMNS = 18 
#     # 資料集一共的欄位數(前九個希望固定為「日期, 成交股數, 成交金額, 成交筆數, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差」)
# OPENING_PRICE_INDEX = 4 # 資料集中「開盤價」欄位的索引
# CLOSING_PRICE_INDEX = 7 # 資料集中「收盤價」欄位的索引
# STATE_VARIABLE_START_INDEX = 10 # 資料集中狀態變數開始的欄位的「索引」(從0開始算)(收盤價MA5)
# STATE_VARIABLE_CONTINUOUS_END_INDEX = STATE_VARIABLE_DISCRETE_START_INDEX - 1 
#     # 資料集中連續型別的狀態變數結束的欄位的索引(漲跌價差.1) (目前希望離散型別的狀態變數接在類別型別的狀態變數之後)
# CURRENT_POSITION_INDEX = 17 # 資料集中「當前資產部位」欄位的索引 (目前希望是位在資料集中最後一個欄位)

# # 以下的超參數並非是調參的重點，能不改就不要改
# N_ACTIONS = 2 # action size (= [0, 1])
# TRANSACTION_COST_RATE = 0.001425 # 參考實際的手續費率

'''
燦坤 變數完整版
'''
# # 以下的超參數必須根據不同的資料集(csv檔)做修改
# YOUR_CSVFILE_PATH = "D:/專案/資料集/燦坤2430_ver2.csv" # 路徑請自己改
# N_STATES = 38 # state size (= [收盤價MA5, 收盤價MA10, ... ,當前資產部位]，一共37個狀態變數)
# STATE_VARIABLE_DISCRETE_START_INDEX = 35 # 資料集中離散(類別)型別的狀態變數開始的欄位的「索引(從0開始算)_」(一月) 

# # 以下的超參數是目前希望特定的欄位在資料集中所在的位置，能不改就不要改
# N_COLUMNS = 48 
#     # 資料集一共的欄位數(前九個希望固定為「日期, 成交股數, 成交金額, 成交筆數, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差」)
# OPENING_PRICE_INDEX = 4 # 資料集中「開盤價」欄位的索引
# CLOSING_PRICE_INDEX = 7 # 資料集中「收盤價」欄位的索引
# STATE_VARIABLE_START_INDEX = 10 # 資料集中狀態變數開始的欄位的「索引」(從0開始算)(收盤價MA5)
# STATE_VARIABLE_CONTINUOUS_END_INDEX = STATE_VARIABLE_DISCRETE_START_INDEX - 1 
#     # 資料集中連續型別的狀態變數結束的欄位的索引(漲跌價差.1) (目前希望離散型別的狀態變數接在類別型別的狀態變數之後)
# CURRENT_POSITION_INDEX = 47 # 資料集中「當前資產部位」欄位的索引 (目前希望是位在資料集中最後一個欄位)

# # 以下的超參數並非是調參的重點，能不改就不要改
# N_ACTIONS = 2 # action size (= [0, 1])
# TRANSACTION_COST_RATE = 0.001425 # 參考實際的手續費率

'''
東元 變數完整版
'''
# # 以下的超參數必須根據不同的資料集(csv檔)做修改
# YOUR_CSVFILE_PATH = "D:/專案/資料集/東元1504_ver1.csv" # 路徑請自己改
# N_STATES = 38 # state size (= [收盤價MA5, 收盤價MA10, ... ,當前資產部位]，一共37個狀態變數)
# STATE_VARIABLE_DISCRETE_START_INDEX = 35 # 資料集中離散(類別)型別的狀態變數開始的欄位的「索引(從0開始算)_」(一月) 

# # 以下的超參數是目前希望特定的欄位在資料集中所在的位置，能不改就不要改
# N_COLUMNS = 48 
#     # 資料集一共的欄位數(前九個希望固定為「日期, 成交股數, 成交金額, 成交筆數, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差」)
# OPENING_PRICE_INDEX = 4 # 資料集中「開盤價」欄位的索引
# CLOSING_PRICE_INDEX = 7 # 資料集中「收盤價」欄位的索引
# STATE_VARIABLE_START_INDEX = 10 # 資料集中狀態變數開始的欄位的「索引」(從0開始算)(收盤價MA5)
# STATE_VARIABLE_CONTINUOUS_END_INDEX = STATE_VARIABLE_DISCRETE_START_INDEX - 1 
#     # 資料集中連續型別的狀態變數結束的欄位的索引(漲跌價差.1) (目前希望離散型別的狀態變數接在類別型別的狀態變數之後)
# CURRENT_POSITION_INDEX = 47 # 資料集中「當前資產部位」欄位的索引 (目前希望是位在資料集中最後一個欄位)

# # 以下的超參數並非是調參的重點，能不改就不要改
# N_ACTIONS = 2 # action size (= [0, 1])
# TRANSACTION_COST_RATE = 0.001425 # 參考實際的手續費率
# Out:
# '\n東元 變數完整版\n'

# %%
class Net(nn.Module):
    '''
        建立現實網路(Target Net)及估計網路(Eval Net)
    '''
    def __init__(self, ):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(N_STATES, 10)
        self.fc1.weight.data.normal_(0, 0.1)   # initialization  
#         self.fc2 = nn.Linear(10, 10)
#         self.fc2.weight.data.normal_(0, 0.1)   # initialization 
        self.out = nn.Linear(10, N_ACTIONS)
        self.out.weight.data.normal_(0, 0.1)   # initialization

    def forward(self, x):
        x = self.fc1(x)
        x = F.relu(x)
#         x = self.fc2(x)
#         x = F.relu(x)
        actions_value = self.out(x)
        return actions_value
    
    def choose_action(self, x):
        x = torch.unsqueeze(torch.FloatTensor(x), 0)
        x = x.reshape(1, x.shape[0], x.shape[1], x.shape[2])
        actions_value = self.forward(x)
        print(actions_value.detach().numpy())
        action = np.argmax(actions_value.detach().numpy())     # return the argmax
        
        return action
    
        '''
        input torch.Size([147, 1, 1, 37])
        
        conv1 torch.Size([147, 16, 1, 19])
        conv2 torch.Size([147, 32, 1, 10])
        conv3 torch.Size([147, 32, 1, 5])
        
        Flat  torch.Size([147, 128])
        fc4   torch.Size([147, 64])
        fc5   torch.Size([147, 2])
        '''

# %%
class DQN(object):
    '''
        具體DQN功能
    '''
    def __init__(self):
        self.eval_net, self.target_net = Net(), Net()
        # 載入上次最好的參數作為起點
#         start_param = torch.load('train_last_best_param_as_start.pkl')
# #         print(start_param)
#         self.eval_net.load_state_dict(start_param)
#         self.target_net.load_state_dict(start_param)
        
        self.learn_step_counter = 0 # 用於target更新計時
        self.memory_counter = 0 # 記憶庫計數
        self.memory = np.zeros((MEMORY_CAPACITY, N_STATES * 2 + 2)) # 初始化記憶庫
        self.optimizer = torch.optim.Adam(self.eval_net.parameters(), lr=LR) # torch的優化器
        self.loss_func = nn.MSELoss() # 誤差公式(MSE)
        
        self.epsilon = EPSILON  # exploration rate
        self.epsilon_min = EPSILON_MIN
        self.epsilon_decay = EPSILON_DECAY

    def choose_action(self, x,hi=False):
        x = torch.unsqueeze(torch.FloatTensor(x), 0)
        
        # 這裡只輸入一個 sample
        if np.random.uniform() > self.epsilon: # 選最優動作
            actions_value = self.eval_net.forward(x)
            if hi:
                print(actions_value)
            #action = torch.max(actions_value, 1)[1].data.numpy()[0, 0] # return the argmax # 這樣action永遠會選到0
            action = np.argmax(actions_value.detach().numpy()) 
        else:   # 隨機選動作
            action = np.random.randint(0, N_ACTIONS)
        return action
    
        

    def store_transition(self, s, a, r, s_):
        transition = np.hstack((s, [a, r], s_))
        # 如果記憶庫滿了，就覆蓋老數據
        index = self.memory_counter % MEMORY_CAPACITY
        self.memory[index, :] = transition
        self.memory_counter += 1

    def learn(self):
        # target net 参數更新
        if self.learn_step_counter % TARGET_REPLACE_ITER == 0:
            self.target_net.load_state_dict(self.eval_net.state_dict())
        self.learn_step_counter += 1

        # 抽取記憶庫中的批數據
        sample_index = np.random.choice(MEMORY_CAPACITY, BATCH_SIZE)
        b_memory = self.memory[sample_index, :]
        b_s = torch.FloatTensor(b_memory[:, :N_STATES])
        b_a = torch.LongTensor(b_memory[:, N_STATES:N_STATES+1].astype(int))
        b_r = torch.FloatTensor(b_memory[:, N_STATES+1:N_STATES+2])
        b_s_ = torch.FloatTensor(b_memory[:, -N_STATES:])
        
        ### double DQN實作 ###
        q_eval = self.eval_net(b_s).gather(1, b_a)  # shape (batch, 1)

        # 取得「Q估計(q_eval)」估計出來的動作
        q_eval_test= self.eval_net(b_s)
        Q1_argmax = np.argmax(q_eval_test.data.numpy(),axis = 1)

        # 用「Q估計(q_eval)」估計出來的動作，取得「Q現實(q_next，和target network，即老神經網路相關)」中的Q值，即q_target
        q_next = self.target_net(b_s_) 
        
        q_next_numpy = q_next.data.numpy()
        q_update = np.zeros((BATCH_SIZE,1))

        for i in range(BATCH_SIZE):
            q_update[i] = q_next_numpy[i , Q1_argmax[i]]

        q_update = GAMMA * q_update
        q_update = torch.FloatTensor(q_update)
        variable11 = Variable(q_update)
        q_target = b_r + variable11
        
        loss = self.loss_func(q_eval, q_target)

        self.loss = loss
        
        # 計算, 更新 eval net
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        
        # 讓隨機選取行動的機率隨著遊玩次數增加而遞減
        if self.epsilon > self.epsilon_min: 
            self.epsilon *= self.epsilon_decay

    def copy_params(self, a):
        self.eval_net.load_state_dict(a)

# %%
# --------------- 主程式 ----------------
            
if __name__ == "__main__": 
    
    # --------------- 資料前置作業 ----------------
    
    # if __name__ == "__main__ 目的在於當該檔案被別的py檔引用時，不會執行以下的程式碼 (別的py檔可以引用上面的class或是def)

    # 載入股市資料集
    csvfile = open(YOUR_CSVFILE_PATH, newline='', encoding='utf-8') # encoding有時可能為utf-8，要注意！
    csvfile_rows = list(csv.reader(csvfile))

    # 資料型態轉換(把大多數的變數的資料型態從str轉成int或是float)
    for i in csvfile_rows[1:]:
        for j in range(1, N_COLUMNS):
            if i[j] != '' and j in [1,2,3] or j in range(STATE_VARIABLE_DISCRETE_START_INDEX, N_COLUMNS):
                i[j] = int(i[j])
            elif i[j] != '':
                i[j] = float(i[j])
            else:
                i[j] = 'NA' # 把空值設成'NA'

    # 取得訓練集
    csvfile_rows_train_start_day = TRAIN_START_DAY
    csvfile_rows_train_start_day_index = -1
    
    csvfile_rows_train_end_day = TRAIN_END_DAY
    csvfile_rows_train_end_day_index = -1
    
    for i in range(0, len(csvfile_rows)):
        if csvfile_rows[i][0] == csvfile_rows_train_start_day:
            csvfile_rows_train_start_day_index = i
        if csvfile_rows[i][0] == csvfile_rows_train_end_day:
            csvfile_rows_train_end_day_index = i
    
    csvfile_rows_train = csvfile_rows[csvfile_rows_train_start_day_index : csvfile_rows_train_end_day_index + 1]
    # csvfile_rows_train_end_day_index要加1的原因是因為[n:m]是從n取到m-1

    # 對訓練集的資料做特徵縮放(feature scaling)
    csvfile_rows_train = np.transpose(csvfile_rows_train)
    csvfile_rows_train = np.ndarray.tolist(csvfile_rows_train)
    for i in csvfile_rows_train[STATE_VARIABLE_START_INDEX : STATE_VARIABLE_CONTINUOUS_END_INDEX + 1]:
        for j in range(0, len(i)):
            i[j] = float(i[j])
    train_mean_list = []
    train_std_list = []
    for i in csvfile_rows_train[STATE_VARIABLE_START_INDEX : STATE_VARIABLE_CONTINUOUS_END_INDEX + 1]:
        status_variable_mean = statistics.mean(i)
        status_variable_stdev = statistics.stdev(i)
        train_mean_list.append(status_variable_mean)
        train_std_list.append(status_variable_stdev)
        for j in range(0, len(i)):
            i[j] = (i[j] - status_variable_mean) / status_variable_stdev
    
    #print(csvfile_rows_train[STATE_VARIABLE_START_INDEX : STATE_VARIABLE_CONTINUOUS_END_INDEX + 1])
        # 查看訓練集是否有做到特徵縮放
    csvfile_rows_train = np.transpose(csvfile_rows_train)
    csvfile_rows_train = np.ndarray.tolist(csvfile_rows_train)
    for i in csvfile_rows_train:
        for j in range(1, N_COLUMNS):
            if i[j] != '' and j in [1,2,3] or j in range(STATE_VARIABLE_DISCRETE_START_INDEX, N_COLUMNS):
                i[j] = int(i[j])
            elif i[j] != '':
                i[j] = float(i[j])
                
    #print(csvfile_rows_train[1:4]) # 查看訓練集是否有在「對的欄位」(連續狀態變數的欄位)做到特徵縮放

    ### 將類別變數轉成獨熱編碼的形式 ###
    # 待補

    csvfile.close()
    
    # 記憶體的大小以訓練集的長度為基礎，會視獎勵函數的設計微調(目前每個episode是從訓練集的第二天跑到訓練集的最後一天，因此要減掉一)
    MEMORY_CAPACITY = len(csvfile_rows_train) - 1 # 以目前訓練集所選的起始、結束日期，並結合獎勵函數來看，記憶體的大小應為735
    
    # 目前暫定每次訓練時從記憶體中選取要訓練的資料的批量大小為記憶體大小的20%
    BATCH_SIZE = round(MEMORY_CAPACITY * BATCH_SIZE_ACCOUNT_FOR_MEMORY_CAPACITY)
    #print(BATCH_SIZE) # 147
    
    dqn = DQN() # 定義DQN系統

    # 建立紀錄performance、transaction times、total reward和loss的列表(list),之後畫圖會用到
    performance_list = []
    transaction_times_list = []
    reward_list = []
    loss_list = []
    
    # 建立一個字典去存神經網路參數(以實體報酬率作為key，其對應的神經網路參數為value)
    param_dict = {}
    param_list = []
    
    episode_start_day_index = 1 # 挑選訓練集第二個交易日為episode開始的日期(因為會用到第一個交易日的狀態變數資料，所以要從第二天開始)
    episode_start_day = csvfile_rows_train[episode_start_day_index][0]

    episode_end_day_index = len(csvfile_rows_train) - 1 # 挑選訓練集倒數第一個交易日為episode結束的日期
    episode_end_day = csvfile_rows_train[episode_end_day_index][0]
    
    training_set_buy_and_hold_return = ((csvfile_rows_train[len(csvfile_rows_train) - 1][OPENING_PRICE_INDEX]
               - csvfile_rows_train[0][OPENING_PRICE_INDEX]) / csvfile_rows_train[0][OPENING_PRICE_INDEX])
    print("在訓練集中，使用B&H的報酬率為：", training_set_buy_and_hold_return)
         
    print("--------------------------以下開始訓練模型-------------------------")

    for i_episode in range(EPISODES):

        # 重新一個EPISODE時把所有訓練資料中的資產持有狀態全部設為0 (開始投資之前不會有資料的資產持有狀態為1，因為根本還沒有開始買股票)
        for i in csvfile_rows_train:
            i[CURRENT_POSITION_INDEX] = 0

        state = csvfile_rows_train[episode_start_day_index - 1][STATE_VARIABLE_START_INDEX:] # 根據日期取得狀態變數
        np.asarray(state, dtype = float)
        state = np.reshape(state, [1, N_STATES]) # 為了讓狀態可以餵進神經網路所做的維度調整

        initial_principal = 100000 # 本金
        cash_hold = initial_principal # agent目前「實際」持有的現金
        transaction_cost_rate = 0.001425 # 交易成本(手續費)比率
        number_of_shares_held = 0 # 持有股數(每一次EPISODE開始前都要歸零)

        done = False # 是否結束該EPISODE(結束條件為在持有股票的狀態下選擇賣掉股票的行動)
        reward = 0 # 獎勵(訓練模型用)
        performance = 0 # 該EPISODE「實際」的投資報酬率

        transaction_times = 0 # 該EPISODE發生的交易次數(買和賣皆算進行一次交易)
        total_reward = 0 #以獎勵總值表示performance

        dqn.memory_counter = 0
        
        buy_price = 0 # 買入股票的價格
        
        maxSellReward = 0 # 買入後的最高賣出報酬
        
        profit = 0 # 賺到的錢，不再拿去投資

        for day in range(episode_start_day_index, episode_end_day_index + 1):

            # 選擇行動
            hi=False
            if i_episode == 999:
                hi=True
            action = dqn.choose_action(state,hi)
#             print(state[0])

            # 當EPISODE進行到倒數第一天時就要強制結束該EPISODE，因為後面沒資料了
            if day == (episode_end_day_index):
                done = True
                if (csvfile_rows_train[day - 1][CURRENT_POSITION_INDEX] == 0): 
                    # 如果t-1期的agent之前持有的是現金，則繼續持有現金(wait)
                    action = 0
                    
                    # 繼續持有現金的獎勵必定為0 (t期agent持有的現金 = t-1期agen持有的現金)
                    reward = 0
                    total_reward += reward
                    
                else:
                    # 如果agent之前持有的是股票，則強制賣出股票(sell)
                    action = 1 
                    
                    # 根據公式計算出agent在賣出股票後將會持有的現金
                    cash_hold = (number_of_shares_held * csvfile_rows_train[day][CLOSING_PRICE_INDEX] 
                                 * (1 - transaction_cost_rate))

                    # 計算賣出股票的獎勵
                    w_t = cash_hold # t期agent持有的現金
#                     w_t_prev =  csvfile_rows_train[day][CLOSING_PRICE_INDEX] * number_of_shares_held 
                    w_t_prev =  buy_price * number_of_shares_held 
                    # t-1期收盤價 * agent持有的股數 
                    reward = math.log(w_t / w_t_prev)
#                     reward = math.log(w_t / 100000)            
                    total_reward += reward

                    # 每賣出一次股票，該EPISODE的交易次數就增加一次
                    transaction_times += 1 
                    if(i_episode == 999):
                        print(day , "最後一期賣")

            # 根據行動計算獎勵
            if csvfile_rows_train[day - 1][CURRENT_POSITION_INDEX] == 0 and done == False:

                if action == 1: # 如果t-1期的當前資產部位為持有現金(current position = 0)，且行動為1(action = 1)，則買入股票(buy)
                    
                    # 買入股票的價格為t期的開盤價
                    #buy_price = csvfile_rows_train[day][OPENING_PRICE_INDEX] 
                    buy_price = csvfile_rows_train[day][CLOSING_PRICE_INDEX]
                    
                    
                    # 根據公式計算出agent在買入股票後將會持有的股數
                    number_of_shares_held = cash_hold  / (buy_price * (1 + transaction_cost_rate))
                    

                    # 計算買入股票的獎勵
                    w_t = csvfile_rows_train[day+1][CLOSING_PRICE_INDEX] * number_of_shares_held # t期收盤價 * agent持有的股數
                    w_t_prev = cash_hold # t-1期agen持有的現金
#                     reward = math.log(w_t/w_t_prev)
                    reward = 0
#                     reward = math.log(w_t / 100000)
                    total_reward += reward
                    
                    # 買入股票後，t期的「資產當前部位」將設為1
                    csvfile_rows_train[day][CURRENT_POSITION_INDEX] = 1
                    
                    # 由於將所有的現金拿去買股票，所以之後agent持有的現金為0
                    cash_hold = 0 
                    
                    # 每買入一次股票，該EPISODE的交易次數就增加一次
                    transaction_times += 1
                    if(i_episode == 999):
                        print(day , "買")
                    
                    
                elif action == 0: # 如果當前資產部位為持有現金(current position = 0)，且行動為1(action = 0)，則繼續持有現金(wait)
                    
                    # 繼續持有現金的獎勵必定為0 (t期agent持有的現金 = t-1期agen持有的現金)
                    # Wait: Min (-Buy Reward, 0)
                    buy_price_cur = csvfile_rows_train[day][CLOSING_PRICE_INDEX]
                    number_of_shares_held_cur = cash_hold  / (buy_price_cur * (1 + transaction_cost_rate))
                    buy_w_t = csvfile_rows_train[day+1][CLOSING_PRICE_INDEX] * number_of_shares_held_cur # t期收盤價 * agent持有的股數
                    buy_w_t_prev = cash_hold # t-1期agen持有的現金
                    buy_reward = math.log(buy_w_t / buy_w_t_prev)
#                     reward = min(-buy_reward,0)
                    reward = 0
#                     reward = math.log(cash_hold / 100000)
                    total_reward += reward

            elif csvfile_rows_train[day - 1][CURRENT_POSITION_INDEX] == 1 and done == False:

                if action == 1: # 如果t-1期的當前資產部位為持有股票(current position = 1)，且行動為1(action = 1)，則賣出股票(sell)
                    
   
                    # 根據公式計算出agent在賣出股票後將會持有的現金
                    cash_hold = (number_of_shares_held * csvfile_rows_train[day][CLOSING_PRICE_INDEX] 
                                 * (1 - transaction_cost_rate))
                    # 計算賣出股票的獎勵
                    w_t = cash_hold # t期agent持有的現金
#                     w_t_prev = csvfile_rows_train[day-1][CLOSING_PRICE_INDEX] * number_of_shares_held # t-n期買價 * agent持有的股數
                    w_t_prev = buy_price * number_of_shares_held
                    reward = math.log(w_t / w_t_prev) 
#                     reward = math.log(w_t / 100000)
                    total_reward += reward 
                    
                    # 每賣出一次股票，該EPISODE的交易次數就增加一次
                    transaction_times += 1 
                    if(i_episode == 999):
                        print(day , "賣")
                    #number_of_shares_held = 0
                    
                    # 若賺的錢超過本金，只拿本金再投資
#                     if cash_hold > initial_principal:
#                         profit += cash_hold - initial_principal
#                         cash_hold = initial_principal
                 
                elif action == 0: # 如果當前資產部位為持有股票(current position = 1)，且行動為0(action = 0)，則繼續持有股票(hold)
                    cash_hold_cur = (number_of_shares_held * csvfile_rows_train[day][CLOSING_PRICE_INDEX] 
                                 * (1 - transaction_cost_rate))
                    sell_w_t = cash_hold_cur # t期agent持有的現金
                    sell_w_t_prev = buy_price * number_of_shares_held
                    sell_reward = math.log(sell_w_t / sell_w_t_prev)
                    if sell_reward > maxSellReward:
                        maxSellReward = sell_reward
                        
                    
                    # 計算繼續持有股票的獎勵
                    w_t = csvfile_rows_train[day+1][CLOSING_PRICE_INDEX] * number_of_shares_held # t期收盤價 * agent持有的股數
#                     w_t_prev = csvfile_rows_train[day][CLOSING_PRICE_INDEX] * number_of_shares_held # t-1期收盤價 * agent持有的股數
                    w_t_prev = buy_price * number_of_shares_held
                    hold_reward = math.log(w_t / w_t_prev)
#                     reward = math.log(w_t / 100000)
#                     reward = 0
#                     if hold_reward > maxSellReward:
#                         reward = hold_reward
#                     else:
#                         reward = 0
#                     reward = hold_reward
                    reward = 0
                    total_reward += reward
                    
                    
                    # 由於繼續持有股票，t期的「資產當前部位」將設為1
                    
                    csvfile_rows_train[day][CURRENT_POSITION_INDEX] = 1
                    
            
            # 取得下一個狀態
            next_state = csvfile_rows_train[day][STATE_VARIABLE_START_INDEX:]

            # 為了讓下一個狀態可以餵進神經網路所做的維度調整
            next_state = np.reshape(next_state, [1, N_STATES]) 

            # 將參數組新增至buffer中
            if day != episode_end_day_index:
                dqn.store_transition(state[0], action, reward, next_state[0]) 
            #print(state[0], action, reward, next_state[0])
            
            # 更新狀態和股票持有的狀態
            state = next_state         
            
            # 每次episode結束時的處理事項
            if done: 
                # 計算實體報酬率
                performance = (cash_hold - initial_principal + profit) / initial_principal
                
                # 紀錄該episode的相關資訊                
                performance_list.append(performance)
                transaction_times_list.append(transaction_times)
                reward_list.append(total_reward)
                
                # 每10個episode才會印出一次結果，以減少系統為了印出資訊所消耗的資源
                if (i_episode + 1) % 10 == 0: 
                    print("episode: {}/{}, epsilon: {:.2}"
                          .format(i_episode + 1, EPISODES, dqn.epsilon)) # 印出當前進行到第幾個episode和當前隨機選擇行動的機率
                    print("該episode開始的日期為:", episode_start_day)
                    print("該episode結束的日期為:", episode_end_day)
                    print('該episode最後持有的現金為：', cash_hold + profit)
                    print('該episode的實際報酬率(績效)為：', performance)
                    print('該episode的交易次數為(買入和賣出股票的次數)：', transaction_times)
                    print("該episode的獎勵總和為：", total_reward)
                    print("該episode已賺得利潤為：", profit)
                    print() # 空一行做為分隔
                    
                # 用字典紀錄實體報酬率及其對應的神經網路參數 (紀錄方式：[實體報酬率] = 神經網路參數)
                # 不過這樣必須假設目前沒有實體報酬率相同的狀況啦...
                # (要在訓練模型之前紀錄，因為訓練後的參數就不會是該episode用來決定action的參數了)
                param_dict[performance] = deepcopy(dqn.eval_net.state_dict())
                param_list.append(deepcopy(dqn.eval_net.state_dict()))
                    # list中的value是「可變的」(mutable)，如果直接在list中存神經網路的參數(變數)，存的值會隨著神經網路參數的改變而改變，
                    # 導致最後list中的參數全部相同(地址皆指向神經網路最新的參數，即最後一個episode之後的神經網路參數)
                    # 解決方案：在存進list中的value加上deepcopy()，該值就不會隨著原本變數的改變而改變
                
                ## 訓練模型 ##
                # 在該episode結束之後訓練一次模型，並記錄loss值
                dqn.learn()
                loss_list.append(dqn.loss)
                if (i_episode + 1) % 10 == 0: 
                    print("訓練後的loss為：", dqn.loss)
                    print() # 空一行做為分隔
                    
                # 訓練模型完後清空memory
#                 if i_episode == EPISODES-1:
#                     memory_decribe = pd.DataFrame(dqn.memory)
#                     print(memory_decribe.describe())
                dqn.memory = np.zeros((MEMORY_CAPACITY, N_STATES * 2 + 2))
                break
# Out:
# 在訓練集中，使用B&H的報酬率為： 0.03151618398637128
# --------------------------以下開始訓練模型-------------------------
# episode: 10/1000, epsilon: 0.96
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 57498.5628704115
# 該episode的實際報酬率(績效)為： -0.425014371295885
# 該episode的交易次數為(買入和賣出股票的次數)： 238
# 該episode的獎勵總和為： -0.38395593958414564
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0070, grad_fn=<MseLossBackward>)
#
# episode: 20/1000, epsilon: 0.91
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 85481.32409282276
# 該episode的實際報酬率(績效)為： -0.1451867590717724
# 該episode的交易次數為(買入和賣出股票的次數)： 260
# 該episode的獎勵總和為： 0.02824586906429502
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0023, grad_fn=<MseLossBackward>)
#
# episode: 30/1000, epsilon: 0.86
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 69974.68718881087
# 該episode的實際報酬率(績效)為： -0.30025312811189125
# 該episode的交易次數為(買入和賣出股票的次數)： 238
# 該episode的獎勵總和為： -0.1875823284533379
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0008, grad_fn=<MseLossBackward>)
#
# episode: 40/1000, epsilon: 0.82
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 74281.25269918698
# 該episode的實際報酬率(績效)為： -0.25718747300813016
# 該episode的交易次數為(買入和賣出股票的次數)： 252
# 該episode的獎勵總和為： -0.11788939306206579
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0009, grad_fn=<MseLossBackward>)
#
# episode: 50/1000, epsilon: 0.78
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 67408.14020029486
# 該episode的實際報酬率(績效)為： -0.3259185979970514
# 該episode的交易次數為(買入和賣出股票的次數)： 220
# 該episode的獎勵總和為： -0.23776597926550194
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0005, grad_fn=<MseLossBackward>)
#
# episode: 60/1000, epsilon: 0.74
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 71625.43572304153
# 該episode的實際報酬率(績效)為： -0.28374564276958464
# 該episode的交易次數為(買入和賣出股票的次數)： 222
# 該episode的獎勵總和為： -0.17565752031553183
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0007, grad_fn=<MseLossBackward>)
#
# episode: 70/1000, epsilon: 0.71
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 80390.51932358503
# 該episode的實際報酬率(績效)為： -0.1960948067641497
# 該episode的交易次數為(買入和賣出股票的次數)： 228
# 該episode的獎勵總和為： -0.05593957140106762
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0004, grad_fn=<MseLossBackward>)
#
# episode: 80/1000, epsilon: 0.67
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 74051.0883395517
# 該episode的實際報酬率(績效)為： -0.259489116604483
# 該episode的交易次數為(買入和賣出股票的次數)： 238
# 該episode的獎勵總和為： -0.130960655550652
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0004, grad_fn=<MseLossBackward>)
#
# episode: 90/1000, epsilon: 0.64
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 59584.48912771872
# 該episode的實際報酬率(績效)為： -0.4041551087228128
# 該episode的交易次數為(買入和賣出股票的次數)： 228
# 該episode的獎勵總和為： -0.35544053110653506
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0003, grad_fn=<MseLossBackward>)
#
# episode: 100/1000, epsilon: 0.61
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 68429.53090130692
# 該episode的實際報酬率(績效)為： -0.3157046909869308
# 該episode的交易次數為(買入和賣出股票的次數)： 216
# 該episode的獎勵總和為： -0.22557526589870533
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0003, grad_fn=<MseLossBackward>)
#
# episode: 110/1000, epsilon: 0.58
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 58749.899182589106
# 該episode的實際報酬率(績效)為： -0.41250100817410895
# 該episode的交易次數為(買入和賣出股票的次數)： 242
# 該episode的獎勵總和為： -0.359578485233252
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0002, grad_fn=<MseLossBackward>)
#
# episode: 120/1000, epsilon: 0.55
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 67806.91018376448
# 該episode的實際報酬率(績效)為： -0.32193089816235515
# 該episode的交易次數為(買入和賣出股票的次數)： 216
# 該episode的獎勵總和為： -0.23471562581086527
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0006, grad_fn=<MseLossBackward>)
#
# episode: 130/1000, epsilon: 0.52
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 59920.87699248918
# 該episode的實際報酬率(績效)為： -0.4007912300751082
# 該episode的交易次數為(買入和賣出股票的次數)： 218
# 該episode的獎勵總和為： -0.35693077486913066
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0004, grad_fn=<MseLossBackward>)
#
# episode: 140/1000, epsilon: 0.5
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 52628.55088632267
# 該episode的實際報酬率(績效)為： -0.4737144911367733
# 該episode的交易次數為(買入和賣出股票的次數)： 228
# 該episode的獎勵總和為： -0.4795770567714018
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0003, grad_fn=<MseLossBackward>)
#
# episode: 150/1000, epsilon: 0.47
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 75827.71922989046
# 該episode的實際報酬率(績效)為： -0.24172280770109544
# 該episode的交易次數為(買入和賣出股票的次數)： 236
# 該episode的獎勵總和為： -0.10867596431899289
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0003, grad_fn=<MseLossBackward>)
#
# episode: 160/1000, epsilon: 0.45
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 80452.6914385097
# 該episode的實際報酬率(績效)為： -0.19547308561490295
# 該episode的交易次數為(買入和賣出股票的次數)： 190
# 該episode的獎勵總和為： -0.08222222146453037
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0002, grad_fn=<MseLossBackward>)
#
# episode: 170/1000, epsilon: 0.43
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 68465.1492830597
# 該episode的實際報酬率(績效)為： -0.315348507169403
# 該episode的交易次數為(買入和賣出股票的次數)： 214
# 該episode的獎勵總和為： -0.22647887511860265
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0002, grad_fn=<MseLossBackward>)
#
# episode: 180/1000, epsilon: 0.41
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 75486.37909514313
# 該episode的實際報酬率(績效)為： -0.2451362090485687
# 該episode的交易次數為(買入和賣出股票的次數)： 196
# 該episode的獎勵總和為： -0.1416673615450021
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0002, grad_fn=<MseLossBackward>)
#
# episode: 190/1000, epsilon: 0.39
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 70048.47136550676
# 該episode的實際報酬率(績效)為： -0.2995152863449324
# 該episode的交易次數為(買入和賣出股票的次數)： 192
# 該episode的獎勵總和為： -0.21928011299396935
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0002, grad_fn=<MseLossBackward>)
#
# episode: 200/1000, epsilon: 0.37
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 66042.93953388203
# 該episode的實際報酬率(績效)為： -0.33957060466117966
# 該episode的交易次數為(買入和賣出股票的次數)： 206
# 該episode的獎勵總和為： -0.26819453445645913
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0001, grad_fn=<MseLossBackward>)
#
# episode: 210/1000, epsilon: 0.35
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 63136.76245831668
# 該episode的實際報酬率(績效)為： -0.3686323754168332
# 該episode的交易次數為(買入和賣出股票的次數)： 216
# 該episode的獎勵總和為： -0.306076529467768
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(7.8305e-05, grad_fn=<MseLossBackward>)
#
# episode: 220/1000, epsilon: 0.33
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 79965.85121406292
# 該episode的實際報酬率(績效)為： -0.20034148785937084
# 該episode的交易次數為(買入和賣出股票的次數)： 174
# 該episode的獎勵總和為： -0.09968375063051649
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0003, grad_fn=<MseLossBackward>)
#
# episode: 230/1000, epsilon: 0.32
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 82614.44713755892
# 該episode的實際報酬率(績效)為： -0.1738555286244108
# 該episode的交易次數為(買入和賣出股票的次數)： 176
# 該episode的獎勵總和為： -0.06567487865264778
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(2.8916e-05, grad_fn=<MseLossBackward>)
#
# episode: 240/1000, epsilon: 0.3
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 72482.39722624852
# 該episode的實際報酬率(績效)為： -0.2751760277375148
# 該episode的交易次數為(買入和賣出股票的次數)： 154
# 該episode的獎勵總和為： -0.21217955535840322
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0003, grad_fn=<MseLossBackward>)
#
# episode: 250/1000, epsilon: 0.29
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 75735.81497237527
# 該episode的實際報酬率(績效)為： -0.24264185027624727
# 該episode的交易次數為(買入和賣出股票的次數)： 168
# 該episode的獎勵總和為： -0.15830422553947057
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(5.2647e-05, grad_fn=<MseLossBackward>)
#
# episode: 260/1000, epsilon: 0.27
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 69847.05220006082
# 該episode的實際報酬率(績效)為： -0.30152947799939184
# 該episode的交易次數為(買入和賣出股票的次數)： 204
# 該episode的獎勵總和為： -0.21361576663214965
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(9.2494e-05, grad_fn=<MseLossBackward>)
#
# episode: 270/1000, epsilon: 0.26
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 75418.79183841725
# 該episode的實際報酬率(績效)為： -0.2458120816158275
# 該episode的交易次數為(買入和賣出股票的次數)： 156
# 該episode的獎勵總和為： -0.1710428326209099
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(9.7500e-05, grad_fn=<MseLossBackward>)
# episode: 280/1000, epsilon: 0.25
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 66390.22105094856
# 該episode的實際報酬率(績效)為： -0.3360977894905144
# 該episode的交易次數為(買入和賣出股票的次數)： 172
# 該episode的獎勵總和為： -0.28715764769309365
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(9.4796e-05, grad_fn=<MseLossBackward>)
#
# episode: 290/1000, epsilon: 0.23
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 75164.50566772725
# 該episode的實際報酬率(績效)為： -0.24835494332272748
# 該episode的交易次數為(買入和賣出股票的次數)： 194
# 該episode的獎勵總和為： -0.14736445740964021
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0001, grad_fn=<MseLossBackward>)
#
# episode: 300/1000, epsilon: 0.22
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 73277.79265186982
# 該episode的實際報酬率(績效)為： -0.2672220734813018
# 該episode的交易次數為(買入和賣出股票的次數)： 158
# 該episode的獎勵總和為： -0.1984177217543022
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0001, grad_fn=<MseLossBackward>)
#
# episode: 310/1000, epsilon: 0.21
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 85565.43093217356
# 該episode的實際報酬率(績效)為： -0.14434569067826436
# 該episode的交易次數為(買入和賣出股票的次數)： 136
# 該episode的獎勵總和為： -0.05905780438858563
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(3.9495e-05, grad_fn=<MseLossBackward>)
#
# episode: 320/1000, epsilon: 0.2
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 81596.49249464668
# 該episode的實際報酬率(績效)為： -0.18403507505353323
# 該episode的交易次數為(買入和賣出股票的次數)： 138
# 該episode的獎勵總和為： -0.10512889915591894
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(5.2631e-05, grad_fn=<MseLossBackward>)
#
# episode: 330/1000, epsilon: 0.19
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 84942.47399656237
# 該episode的實際報酬率(績效)為： -0.15057526003437627
# 該episode的交易次數為(買入和賣出股票的次數)： 164
# 該episode的獎勵總和為： -0.04642911174199796
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(7.0355e-05, grad_fn=<MseLossBackward>)
#
# episode: 340/1000, epsilon: 0.18
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 79859.38461259844
# 該episode的實際報酬率(績效)為： -0.2014061538740156
# 該episode的交易次數為(買入和賣出股票的次數)： 132
# 該episode的獎勵總和為： -0.13091973724328804
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(9.3242e-05, grad_fn=<MseLossBackward>)
#
# episode: 350/1000, epsilon: 0.17
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 99785.62347544242
# 該episode的實際報酬率(績效)為： -0.0021437652455757778
# 該episode的交易次數為(買入和賣出股票的次數)： 158
# 該episode的獎勵總和為： 0.11034880003072442
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(3.4929e-05, grad_fn=<MseLossBackward>)
#
# episode: 360/1000, epsilon: 0.17
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 88454.77919115376
# 該episode的實際報酬率(績效)為： -0.11545220808846236
# 該episode的交易次數為(買入和賣出股票的次數)： 130
# 該episode的獎勵總和為： -0.03011966683902153
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(6.2751e-05, grad_fn=<MseLossBackward>)
#
# episode: 370/1000, epsilon: 0.16
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 79033.84451632382
# 該episode的實際報酬率(績效)為： -0.2096615548367618
# 該episode的交易次數為(買入和賣出股票的次數)： 70
# 該episode的獎勵總和為： -0.18545451587848114
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(7.4540e-05, grad_fn=<MseLossBackward>)
#
# episode: 380/1000, epsilon: 0.15
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 90279.5894009888
# 該episode的實際報酬率(績效)為： -0.097204105990112
# 該episode的交易次數為(買入和賣出股票的次數)： 120
# 該episode的獎勵總和為： -0.01681964304977798
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(5.7973e-05, grad_fn=<MseLossBackward>)
#
# episode: 390/1000, epsilon: 0.14
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 85140.3031767313
# 該episode的實際報酬率(績效)為： -0.14859696823268706
# 該episode的交易次數為(買入和賣出股票的次數)： 112
# 該episode的獎勵總和為： -0.08112646821743234
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(3.2067e-05, grad_fn=<MseLossBackward>)
#
# episode: 400/1000, epsilon: 0.14
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 101050.97913267129
# 該episode的實際報酬率(績效)為： 0.010509791326712875
# 該episode的交易次數為(買入和賣出股票的次數)： 86
# 該episode的獎勵總和為： 0.07168633039439301
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(1.6117e-05, grad_fn=<MseLossBackward>)
#
# episode: 410/1000, epsilon: 0.13
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 85721.27872453441
# 該episode的實際報酬率(績效)為： -0.14278721275465592
# 該episode的交易次數為(買入和賣出股票的次數)： 112
# 該episode的獎勵總和為： -0.07432590157861238
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(5.7118e-05, grad_fn=<MseLossBackward>)
#
# episode: 420/1000, epsilon: 0.12
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 98783.96508853268
# 該episode的實際報酬率(績效)為： -0.012160349114673154
# 該episode的交易次數為(買入和賣出股票的次數)： 72
# 該episode的獎勵總和為： 0.03902859235604924
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(6.1320e-05, grad_fn=<MseLossBackward>)
#
# episode: 430/1000, epsilon: 0.12
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 86059.78595172368
# 該episode的實際報酬率(績效)為： -0.1394021404827632
# 該episode的交易次數為(買入和賣出股票的次數)： 80
# 該episode的獎勵總和為： -0.09316851973823409
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(9.1659e-06, grad_fn=<MseLossBackward>)
#
# episode: 440/1000, epsilon: 0.11
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 85661.64967254248
# 該episode的實際報酬率(績效)為： -0.1433835032745752
# 該episode的交易次數為(買入和賣出股票的次數)： 110
# 該episode的獎勵總和為： -0.07644574480372615
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(5.4607e-05, grad_fn=<MseLossBackward>)
#
# episode: 450/1000, epsilon: 0.11
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 74980.5319538179
# 該episode的實際報酬率(績效)為： -0.250194680461821
# 該episode的交易次數為(買入和賣出股票的次數)： 78
# 該episode的獎勵總和為： -0.23240623970635402
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(1.2386e-05, grad_fn=<MseLossBackward>)
#
# episode: 460/1000, epsilon: 0.1
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 92037.1859290978
# 該episode的實際報酬率(績效)為： -0.07962814070902197
# 該episode的交易次數為(買入和賣出股票的次數)： 58
# 該episode的獎勵總和為： -0.04168191184280076
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(3.6706e-05, grad_fn=<MseLossBackward>)
#
# episode: 470/1000, epsilon: 0.095
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 96875.99407778111
# 該episode的實際報酬率(績效)為： -0.031240059222188865
# 該episode的交易次數為(買入和賣出股票的次數)： 44
# 該episode的獎勵總和為： -0.00041075259678733517
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(3.4686e-05, grad_fn=<MseLossBackward>)
#
# episode: 480/1000, epsilon: 0.091
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 89779.52308148227
# 該episode的實際報酬率(績效)為： -0.10220476918517728
# 該episode的交易次數為(買入和賣出股票的次數)： 66
# 該episode的獎勵總和為： -0.060821738244572904
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(4.4055e-05, grad_fn=<MseLossBackward>)
#
# episode: 490/1000, epsilon: 0.086
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 91367.10533057938
# 該episode的實際報酬率(績效)為： -0.08632894669420624
# 該episode的交易次數為(買入和賣出股票的次數)： 86
# 該episode的獎勵總和為： -0.029053287227931705
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(8.0873e-05, grad_fn=<MseLossBackward>)
#
# episode: 500/1000, epsilon: 0.082
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 89229.08154055112
# 該episode的實際報酬率(績效)為： -0.10770918459448876
# 該episode的交易次數為(買入和賣出股票的次數)： 56
# 該episode的獎勵總和為： -0.07409157506928966
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(5.3718e-06, grad_fn=<MseLossBackward>)
#
# episode: 510/1000, epsilon: 0.078
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 85095.5217709814
# 該episode的實際報酬率(績效)為： -0.14904478229018597
# 該episode的交易次數為(買入和賣出股票的次數)： 102
# 該episode的獎勵總和為： -0.08877250672923503
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(6.7008e-05, grad_fn=<MseLossBackward>)
#
# episode: 520/1000, epsilon: 0.074
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 92234.39579340488
# 該episode的實際報酬率(績效)為： -0.07765604206595118
# 該episode的交易次數為(買入和賣出股票的次數)： 54
# 該episode的獎勵總和為： -0.04238945608868727
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(1.5791e-05, grad_fn=<MseLossBackward>)
#
# episode: 530/1000, epsilon: 0.071
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 96905.39314892353
# 該episode的實際報酬率(績效)為： -0.030946068510764743
# 該episode的交易次數為(買入和賣出股票的次數)： 46
# 該episode的獎勵總和為： 0.0013166581848754466
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(5.6567e-05, grad_fn=<MseLossBackward>)
#
# episode: 540/1000, epsilon: 0.067
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 86553.96017190718
# 該episode的實際報酬率(績效)為： -0.1344603982809282
# 該episode的交易次數為(買入和賣出股票的次數)： 74
# 該episode的獎勵總和為： -0.09171468043930762
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(9.2770e-06, grad_fn=<MseLossBackward>)
# episode: 550/1000, epsilon: 0.064
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 87776.96430853228
# 該episode的實際報酬率(績效)為： -0.12223035691467725
# 該episode的交易次數為(買入和賣出股票的次數)： 54
# 該episode的獎勵總和為： -0.09192347269987325
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(3.2800e-05, grad_fn=<MseLossBackward>)
#
# episode: 560/1000, epsilon: 0.061
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 97045.37088061283
# 該episode的實際報酬率(績效)為： -0.02954629119387173
# 該episode的交易次數為(買入和賣出股票的次數)： 38
# 該episode的獎勵總和為： -0.002935848434876159
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(3.2473e-05, grad_fn=<MseLossBackward>)
#
# episode: 570/1000, epsilon: 0.058
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 90741.60946808802
# 該episode的實際報酬率(績效)為： -0.09258390531911981
# 該episode的交易次數為(買入和賣出股票的次數)： 66
# 該episode的獎勵總和為： -0.05016264828595814
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(1.0757e-05, grad_fn=<MseLossBackward>)
#
# episode: 580/1000, epsilon: 0.055
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 86399.57506103787
# 該episode的實際報酬率(績效)為： -0.13600424938962125
# 該episode的交易次數為(買入和賣出股票的次數)： 50
# 該episode的獎勵總和為： -0.11058778718977112
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(1.1558e-05, grad_fn=<MseLossBackward>)
#
# episode: 590/1000, epsilon: 0.052
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 89176.89342398249
# 該episode的實際報酬率(績效)為： -0.10823106576017512
# 該episode的交易次數為(買入和賣出股票的次數)： 44
# 該episode的獎勵總和為： -0.08322053796904508
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(5.1270e-05, grad_fn=<MseLossBackward>)
#
# episode: 600/1000, epsilon: 0.05
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 73401.7440151178
# 該episode的實際報酬率(績效)為： -0.26598255984882196
# 該episode的交易次數為(買入和賣出股票的次數)： 70
# 該episode的獎勵總和為： -0.25938299244034524
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0001, grad_fn=<MseLossBackward>)
#
# episode: 610/1000, epsilon: 0.047
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 84388.81554012332
# 該episode的實際報酬率(績效)為： -0.15611184459876676
# 該episode的交易次數為(買入和賣出股票的次數)： 70
# 該episode的獎勵總和為： -0.11989581267888802
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(1.0555e-05, grad_fn=<MseLossBackward>)
#
# episode: 620/1000, epsilon: 0.045
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 76536.92072735564
# 該episode的實際報酬率(績效)為： -0.2346307927264436
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode的獎勵總和為： -0.23749323902268826
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(2.2387e-05, grad_fn=<MseLossBackward>)
#
# episode: 630/1000, epsilon: 0.043
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 95377.29784538977
# 該episode的實際報酬率(績效)為： -0.04622702154610233
# 該episode的交易次數為(買入和賣出股票的次數)： 34
# 該episode的獎勵總和為： -0.02312184786312941
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(7.5495e-07, grad_fn=<MseLossBackward>)
#
# episode: 640/1000, epsilon: 0.041
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 87600.19026491935
# 該episode的實際報酬率(績效)為： -0.1239980973508065
# 該episode的交易次數為(買入和賣出股票的次數)： 66
# 該episode的獎勵總和為： -0.08539548959057083
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(2.1895e-06, grad_fn=<MseLossBackward>)
#
# episode: 650/1000, epsilon: 0.039
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 97430.25186588457
# 該episode的實際報酬率(績效)為： -0.025697481341154342
# 該episode的交易次數為(買入和賣出股票的次數)： 36
# 該episode的獎勵總和為： -0.00040168774006525427
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(5.3296e-05, grad_fn=<MseLossBackward>)
#
# episode: 660/1000, epsilon: 0.037
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 102436.29054196485
# 該episode的實際報酬率(績效)為： 0.02436290541964845
# 該episode的交易次數為(買入和賣出股票的次數)： 28
# 該episode的獎勵總和為： 0.04400666277064762
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(6.3247e-06, grad_fn=<MseLossBackward>)
#
# episode: 670/1000, epsilon: 0.035
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 87386.67451585327
# 該episode的實際報酬率(績效)為： -0.12613325484146728
# 該episode的交易次數為(買入和賣出股票的次數)： 52
# 該episode的獎勵總和為： -0.0978037535178689
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(6.4808e-06, grad_fn=<MseLossBackward>)
#
# episode: 680/1000, epsilon: 0.033
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 94253.96488503006
# 該episode的實際報酬率(績效)為： -0.05746035114969942
# 該episode的交易次數為(買入和賣出股票的次數)： 56
# 該episode的獎勵總和為： -0.019305694570635322
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(2.4667e-05, grad_fn=<MseLossBackward>)
#
# episode: 690/1000, epsilon: 0.032
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 90036.06279569407
# 該episode的實際報酬率(績效)為： -0.09963937204305927
# 該episode的交易次數為(買入和賣出股票的次數)： 30
# 該episode的獎勵總和為： -0.08360011342053153
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(5.5417e-06, grad_fn=<MseLossBackward>)
#
# episode: 700/1000, epsilon: 0.03
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 104261.63986039752
# 該episode的實際報酬率(績效)為： 0.04261639860397525
# 該episode的交易次數為(買入和賣出股票的次數)： 32
# 該episode的獎勵總和為： 0.06451709221147112
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(4.8646e-05, grad_fn=<MseLossBackward>)
#
# episode: 710/1000, epsilon: 0.029
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 89655.36098020354
# 該episode的實際報酬率(績效)為： -0.10344639019796464
# 該episode的交易次數為(買入和賣出股票的次數)： 22
# 該episode的獎勵總和為： -0.09353334656528299
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(3.9733e-07, grad_fn=<MseLossBackward>)
#
# episode: 720/1000, epsilon: 0.027
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 105821.91156404279
# 該episode的實際報酬率(績效)為： 0.058219115640427914
# 該episode的交易次數為(買入和賣出股票的次數)： 18
# 該episode的獎勵總和為： 0.06940328648215999
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(5.8872e-07, grad_fn=<MseLossBackward>)
#
# episode: 730/1000, epsilon: 0.026
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 102249.45504961176
# 該episode的實際報酬率(績效)為： 0.02249455049611759
# 該episode的交易次數為(買入和賣出股票的次數)： 14
# 該episode的獎勵總和為： 0.03221317888958832
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(6.6386e-07, grad_fn=<MseLossBackward>)
#
# episode: 740/1000, epsilon: 0.025
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 88723.88586967149
# 該episode的實際報酬率(績效)為： -0.11276114130328511
# 該episode的交易次數為(買入和賣出股票的次數)： 26
# 該episode的獎勵總和為： -0.1011292311895316
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0001, grad_fn=<MseLossBackward>)
#
# episode: 750/1000, epsilon: 0.023
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 99185.89611821879
# 該episode的實際報酬率(績效)為： -0.008141038817812078
# 該episode的交易次數為(買入和賣出股票的次數)： 34
# 該episode的獎勵總和為： 0.01603339803439713
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0002, grad_fn=<MseLossBackward>)
#
# episode: 760/1000, epsilon: 0.022
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 86660.06460477972
# 該episode的實際報酬率(績效)為： -0.1333993539522028
# 該episode的交易次數為(買入和賣出股票的次數)： 34
# 該episode的獎勵總和為： -0.11896926811220242
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(1.1559e-05, grad_fn=<MseLossBackward>)
#
# episode: 770/1000, epsilon: 0.021
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 105087.09321461392
# 該episode的實際報酬率(績效)為： 0.05087093214613924
# 該episode的交易次數為(買入和賣出股票的次數)： 20
# 該episode的獎勵總和為： 0.06385913605523688
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(5.4624e-07, grad_fn=<MseLossBackward>)
#
# episode: 780/1000, epsilon: 0.02
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 100915.30629260915
# 該episode的實際報酬率(績效)為： 0.009153062926091516
# 該episode的交易次數為(買入和賣出股票的次數)： 16
# 該episode的獎勵總和為： 0.020503312721950776
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(2.0211e-06, grad_fn=<MseLossBackward>)
#
# episode: 790/1000, epsilon: 0.019
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 103959.20713670152
# 該episode的實際報酬率(績效)為： 0.03959207136701516
# 該episode的交易次數為(買入和賣出股票的次數)： 8
# 該episode的獎勵總和為： 0.044524339741306915
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(3.6724e-05, grad_fn=<MseLossBackward>)
#
# episode: 800/1000, epsilon: 0.018
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 101816.77137521926
# 該episode的實際報酬率(績效)為： 0.01816771375219265
# 該episode的交易次數為(買入和賣出股票的次數)： 12
# 該episode的獎勵總和為： 0.026548566748022556
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(2.0311e-07, grad_fn=<MseLossBackward>)
#
# episode: 810/1000, epsilon: 0.017
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 85283.77736292694
# 該episode的實際報酬率(績效)為： -0.14716222637073065
# 該episode的交易次數為(買入和賣出股票的次數)： 22
# 該episode的獎勵總和為： -0.14352209073496824
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(1.2797e-06, grad_fn=<MseLossBackward>)
# episode: 820/1000, epsilon: 0.016
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 82465.20648247203
# 該episode的實際報酬率(績效)為： -0.17534793517527972
# 該episode的交易次數為(買入和賣出股票的次數)： 26
# 該episode的獎勵總和為： -0.17428190774779168
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(3.6725e-07, grad_fn=<MseLossBackward>)
#
# episode: 830/1000, epsilon: 0.016
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 91703.86745349978
# 該episode的實際報酬率(績效)為： -0.08296132546500215
# 該episode的交易次數為(買入和賣出股票的次數)： 4
# 該episode的獎勵總和為： -0.08375766124755232
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(3.4489e-07, grad_fn=<MseLossBackward>)
#
# episode: 840/1000, epsilon: 0.015
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 97742.24883217934
# 該episode的實際報酬率(績效)為： -0.02257751167820665
# 該episode的交易次數為(買入和賣出股票的次數)： 4
# 該episode的獎勵總和為： -0.019988314799145042
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(4.9637e-07, grad_fn=<MseLossBackward>)
#
# episode: 850/1000, epsilon: 0.014
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 106687.20895182138
# 該episode的實際報酬率(績效)為： 0.06687208951821376
# 該episode的交易次數為(買入和賣出股票的次數)： 18
# 該episode的獎勵總和為： 0.07754695737814844
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(4.8888e-06, grad_fn=<MseLossBackward>)
#
# episode: 860/1000, epsilon: 0.013
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 95728.94931683884
# 該episode的實際報酬率(績效)為： -0.04271050683161157
# 該episode的交易次數為(買入和賣出股票的次數)： 24
# 該episode的獎勵總和為： -0.026561604762666814
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(7.5568e-06, grad_fn=<MseLossBackward>)
#
# episode: 870/1000, epsilon: 0.013
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 99218.52272927124
# 該episode的實際報酬率(績效)為： -0.007814772707287629
# 該episode的交易次數為(買入和賣出股票的次數)： 52
# 該episode的獎勵總和為： 0.029178158860178077
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(4.8441e-05, grad_fn=<MseLossBackward>)
#
# episode: 880/1000, epsilon: 0.012
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 96812.80456266977
# 該episode的實際報酬率(績效)為： -0.031871954373302286
# 該episode的交易次數為(買入和賣出股票的次數)： 16
# 該episode的獎勵總和為： -0.020999036705479757
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(3.2114e-07, grad_fn=<MseLossBackward>)
#
# episode: 890/1000, epsilon: 0.012
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 90569.9595775543
# 該episode的實際報酬率(績效)為： -0.09430040422445701
# 該episode的交易次數為(買入和賣出股票的次數)： 16
# 該episode的獎勵總和為： -0.0876557147048413
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(2.3765e-07, grad_fn=<MseLossBackward>)
#
# episode: 900/1000, epsilon: 0.011
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 108020.0868834782
# 該episode的實際報酬率(績效)為： 0.08020086883478202
# 該episode的交易次數為(買入和賣出股票的次數)： 20
# 該episode的獎勵總和為： 0.09138687001420284
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(0.0002, grad_fn=<MseLossBackward>)
#
# episode: 910/1000, epsilon: 0.01
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 89297.86369497619
# 該episode的實際報酬率(績效)為： -0.10702136305023814
# 該episode的交易次數為(買入和賣出股票的次數)： 28
# 該episode的獎勵總和為： -0.09325682206617208
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(3.2623e-06, grad_fn=<MseLossBackward>)
#
# episode: 920/1000, epsilon: 0.01
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 97043.1503177924
# 該episode的實際報酬率(績效)為： -0.029568496822075976
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode的獎勵總和為： -0.0001107590921325119
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(7.7903e-05, grad_fn=<MseLossBackward>)
#
# episode: 930/1000, epsilon: 0.01
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 83941.53976218765
# 該episode的實際報酬率(績效)為： -0.16058460237812353
# 該episode的交易次數為(買入和賣出股票的次數)： 60
# 該episode的獎勵總和為： -0.13233001511556386
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(1.2486e-05, grad_fn=<MseLossBackward>)
#
# episode: 940/1000, epsilon: 0.01
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 98242.61009570344
# 該episode的實際報酬率(績效)為： -0.017573899042965642
# 該episode的交易次數為(買入和賣出股票的次數)： 52
# 該episode的獎勵總和為： 0.019293473548006743
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(1.8291e-06, grad_fn=<MseLossBackward>)
#
# episode: 950/1000, epsilon: 0.01
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 92725.04241512569
# 該episode的實際報酬率(績效)為： -0.07274957584874311
# 該episode的交易次數為(買入和賣出股票的次數)： 50
# 該episode的獎勵總和為： -0.03993196390787732
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(6.5242e-06, grad_fn=<MseLossBackward>)
#
# episode: 960/1000, epsilon: 0.01
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 89752.25676157094
# 該episode的實際報酬率(績效)為： -0.10247743238429059
# 該episode的交易次數為(買入和賣出股票的次數)： 52
# 該episode的獎勵總和為： -0.07109338703366394
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(2.8134e-05, grad_fn=<MseLossBackward>)
#
# episode: 970/1000, epsilon: 0.01
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 89270.48959093358
# 該episode的實際報酬率(績效)為： -0.10729510409066424
# 該episode的交易次數為(買入和賣出股票的次數)： 34
# 該episode的獎勵總和為： -0.08929146036085929
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(1.4039e-06, grad_fn=<MseLossBackward>)
#
# episode: 980/1000, epsilon: 0.01
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 90734.00196724747
# 該episode的實際報酬率(績效)為： -0.09265998032752526
# 該episode的交易次數為(買入和賣出股票的次數)： 30
# 該episode的獎勵總和為： -0.07587823048051451
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(2.2352e-06, grad_fn=<MseLossBackward>)
#
# episode: 990/1000, epsilon: 0.01
# 該episode開始的日期為: 2014/1/3
# 該episode結束的日期為: 2015/12/31
# 該episode最後持有的現金為： 90336.47636608023
# 該episode的實際報酬率(績效)為： -0.09663523633919772
# 該episode的交易次數為(買入和賣出股票的次數)： 28
# 該episode的獎勵總和為： -0.08169306154710139
# 該episode已賺得利潤為： 0
#
# 訓練後的loss為： tensor(4.7427e-07, grad_fn=<MseLossBackward>)
#
# tensor([[[0.0007, 0.0020]]], grad_fn=<AddBackward0>)
# 1 買
# tensor([[[6.5701e-04, 4.9464e-05]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0006, -0.0022]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0006, -0.0020]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0006, -0.0017]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0005, -0.0046]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0006, -0.0022]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0006, -0.0017]]], grad_fn=<AddBackward0>)
# tensor([[[0.0008, 0.0033]]], grad_fn=<AddBackward0>)
# 9 賣
# tensor([[[ 0.0005, -0.0051]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0005, -0.0051]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0005, -0.0043]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0006, -0.0018]]], grad_fn=<AddBackward0>)
# tensor([[[0.0007, 0.0006]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0006, -0.0006]]], grad_fn=<AddBackward0>)
# tensor([[[6.4653e-04, 2.6442e-05]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0005, -0.0044]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0005, -0.0070]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0004, -0.0066]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0004, -0.0062]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0001, -0.0146]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0003, -0.0100]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0003, -0.0107]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0001, -0.0146]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0003, -0.0100]]], grad_fn=<AddBackward0>)
# tensor([[[-0.0001, -0.0222]]], grad_fn=<AddBackward0>)
# tensor([[[-6.3787e-05, -2.0391e-02]]], grad_fn=<AddBackward0>)
# tensor([[[-0.0001, -0.0219]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0001, -0.0145]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0002, -0.0136]]], grad_fn=<AddBackward0>)
# tensor([[[ 1.0334e-05, -1.8233e-02]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0002, -0.0128]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0001, -0.0143]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0002, -0.0137]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0003, -0.0091]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0006, -0.0024]]], grad_fn=<AddBackward0>)
# tensor([[[0.0006, 0.0001]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0005, -0.0037]]], grad_fn=<AddBackward0>)
# tensor([[[ 7.9479e-05, -1.6220e-02]]], grad_fn=<AddBackward0>)
# tensor([[[-8.0568e-05, -2.0880e-02]]], grad_fn=<AddBackward0>)
# 41 買
# tensor([[[ 0.0001, -0.0154]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0003, -0.0097]]], grad_fn=<AddBackward0>)
# tensor([[[-0.0003, -0.0263]]], grad_fn=<AddBackward0>)
# tensor([[[ 9.1934e-05, -1.4552e-02]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0002, -0.0130]]], grad_fn=<AddBackward0>)
# tensor([[[-3.3075e-05, -1.9497e-02]]], grad_fn=<AddBackward0>)
# tensor([[[ 2.7500e-05, -1.7733e-02]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0002, -0.0125]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0005, -0.0037]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0004, -0.0068]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0004, -0.0073]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0003, -0.0112]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0004, -0.0074]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0002, -0.0133]]], grad_fn=<AddBackward0>)
# tensor([[[ 8.6297e-05, -1.6022e-02]]], grad_fn=<AddBackward0>)
# tensor([[[-0.0003, -0.0265]]], grad_fn=<AddBackward0>)
# tensor([[[-0.0006, -0.0302]]], grad_fn=<AddBackward0>)
# tensor([[[-0.0001, -0.0223]]], grad_fn=<AddBackward0>)
# tensor([[[-1.5609e-05, -1.8988e-02]]], grad_fn=<AddBackward0>)
# tensor([[[-0.0001, -0.0226]]], grad_fn=<AddBackward0>)
# tensor([[[-7.0626e-05, -2.0590e-02]]], grad_fn=<AddBackward0>)
# tensor([[[-0.0002, -0.0234]]], grad_fn=<AddBackward0>)
# tensor([[[-8.9986e-05, -2.1154e-02]]], grad_fn=<AddBackward0>)
# tensor([[[-1.3870e-05, -1.8938e-02]]], grad_fn=<AddBackward0>)
# tensor([[[-6.2940e-05, -2.0366e-02]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0002, -0.0140]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0003, -0.0092]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0002, -0.0121]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0004, -0.0068]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0003, -0.0092]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0004, -0.0077]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0004, -0.0065]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0001, -0.0127]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0003, -0.0112]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0004, -0.0063]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0005, -0.0039]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0005, -0.0026]]], grad_fn=<AddBackward0>)
# tensor([[[0.0007, 0.0028]]], grad_fn=<AddBackward0>)
# 79 賣
# tensor([[[ 0.0005, -0.0040]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0006, -0.0013]]], grad_fn=<AddBackward0>)
# tensor([[[0.0008, 0.0013]]], grad_fn=<AddBackward0>)
# 82 買
# tensor([[[0.0008, 0.0039]]], grad_fn=<AddBackward0>)
# 83 賣
# tensor([[[0.0010, 0.0091]]], grad_fn=<AddBackward0>)
# 84 買
# tensor([[[0.0012, 0.0131]]], grad_fn=<AddBackward0>)
# 85 賣
# tensor([[[0.0010, 0.0074]]], grad_fn=<AddBackward0>)
# 86 買
# tensor([[[0.0010, 0.0084]]], grad_fn=<AddBackward0>)
# 87 賣
# tensor([[[0.0008, 0.0028]]], grad_fn=<AddBackward0>)
# 88 買
# tensor([[[0.0010, 0.0083]]], grad_fn=<AddBackward0>)
# 89 賣
# tensor([[[0.0008, 0.0024]]], grad_fn=<AddBackward0>)
# 90 買
# tensor([[[0.0010, 0.0083]]], grad_fn=<AddBackward0>)
# 91 賣
# tensor([[[ 0.0004, -0.0080]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0004, -0.0084]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0005, -0.0058]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0006, -0.0050]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0004, -0.0113]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0005, -0.0068]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0005, -0.0070]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0004, -0.0103]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0006, -0.0040]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0007, -0.0021]]], grad_fn=<AddBackward0>)
# tensor([[[0.0009, 0.0012]]], grad_fn=<AddBackward0>)
# 102 買
# tensor([[[0.0010, 0.0053]]], grad_fn=<AddBackward0>)
# 103 賣
# tensor([[[0.0011, 0.0033]]], grad_fn=<AddBackward0>)
# 104 買
# tensor([[[0.0010, 0.0055]]], grad_fn=<AddBackward0>)
# 105 賣
# tensor([[[0.0011, 0.0051]]], grad_fn=<AddBackward0>)
# 106 買
# tensor([[[0.0012, 0.0093]]], grad_fn=<AddBackward0>)
# 107 賣
# tensor([[[0.0014, 0.0099]]], grad_fn=<AddBackward0>)
# 108 買
# tensor([[[0.0015, 0.0122]]], grad_fn=<AddBackward0>)
# 109 賣
# tensor([[[0.0014, 0.0068]]], grad_fn=<AddBackward0>)
# 110 買
# tensor([[[0.0015, 0.0085]]], grad_fn=<AddBackward0>)
# 111 賣
# tensor([[[0.0014, 0.0077]]], grad_fn=<AddBackward0>)
# 112 買
# tensor([[[0.0016, 0.0091]]], grad_fn=<AddBackward0>)
# 113 賣
# tensor([[[0.0013, 0.0043]]], grad_fn=<AddBackward0>)
# 114 買
# tensor([[[0.0016, 0.0110]]], grad_fn=<AddBackward0>)
# 115 賣
# tensor([[[0.0014, 0.0042]]], grad_fn=<AddBackward0>)
# 116 買
# tensor([[[0.0015, 0.0069]]], grad_fn=<AddBackward0>)
# 117 賣
# tensor([[[0.0014, 0.0042]]], grad_fn=<AddBackward0>)
# 118 買
# tensor([[[ 0.0009, -0.0154]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0009, -0.0125]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0007, -0.0139]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0006, -0.0143]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0004, -0.0168]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0005, -0.0144]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0004, -0.0159]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0005, -0.0120]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0003, -0.0149]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0004, -0.0119]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0003, -0.0120]]], grad_fn=<AddBackward0>)
# tensor([[[-3.0191e-05, -1.8937e-02]]], grad_fn=<AddBackward0>)
# tensor([[[-0.0001, -0.0230]]], grad_fn=<AddBackward0>)
# tensor([[[ 3.0253e-05, -2.0961e-02]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0002, -0.0170]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0004, -0.0119]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0003, -0.0124]]], grad_fn=<AddBackward0>)
# tensor([[[-2.1052e-05, -1.9428e-02]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0001, -0.0177]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0001, -0.0168]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0002, -0.0141]]], grad_fn=<AddBackward0>)
# tensor([[[-0.0001, -0.0226]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0005, -0.0137]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0006, -0.0098]]], grad_fn=<AddBackward0>)
# tensor([[[ 4.7010e-05, -2.3165e-02]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0003, -0.0170]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0004, -0.0163]]], grad_fn=<AddBackward0>)
# tensor([[[-1.9391e-05, -2.3912e-02]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0003, -0.0171]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0001, -0.0203]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0003, -0.0161]]], grad_fn=<AddBackward0>)
# tensor([[[ 0.0003, -0.0146]]], grad_fn=<AddBackward0>)
# tensor([[[ 6.5799e-05, -1.8764e-02]]], grad_fn=<AddBackward0>)
# tensor([[[
sortPerformance = sorted(performance_list, reverse = True)
sortPerformance50 = sortPerformance[:50]
# len(sortPerformance50)

# 交易次數是報酬率前50的交易次數
# 再從以排序的報酬率列表中，用報酬率為key，抓原始報酬率列表的index(第幾個episode)
# 再用這個index丟正確的交易次數進去sortTradetimes
sortTradetimes = []
for p in sortPerformance50:
    trade_idx = sort_dict.get(p)
    sortTradetimes.append(transaction_times_list[trade_idx])
    
print(sortTradetimes)
# Out:
# [64, 38, 20, 2, 26, 62, 38, 16, 48, 10, 62, 42, 68, 20, 18, 8, 14, 36, 60, 72, 38, 26, 24, 76, 34, 46, 26, 18, 36, 8, 38, 34, 20, 40, 50, 46, 2, 34, 18, 20, 20, 48, 20, 86, 28, 54, 34, 50, 42, 18]

# %%
performance_list
transaction_times_list
# Out:
# [268,
#  226,
#  260,
#  248,
#  242,
#  232,
#  234,
#  254,
#  264,
#  238,
#  236,
#  258,
#  242,
#  262,
#  260,
#  234,
#  238,
#  270,
#  256,
#  260,
#  258,
#  262,
#  226,
#  230,
#  236,
#  228,
#  240,
#  240,
#  236,
#  238,
#  242,
#  234,
#  262,
#  262,
#  258,
#  238,
#  250,
#  270,
#  252,
#  252,
#  260,
#  266,
#  248,
#  246,
#  248,
#  238,
#  228,
#  214,
#  210,
#  220,
#  218,
#  218,
#  228,
#  234,
#  220,
#  216,
#  220,
#  244,
#  236,
#  222,
#  244,
#  266,
#  250,
#  264,
#  228,
#  252,
#  244,
#  238,
#  246,
#  228,
#  248,
#  234,
#  232,
#  214,
#  234,
#  226,
#  216,
#  228,
#  222,
#  238,
#  222,
#  224,
#  226,
#  230,
#  232,
#  216,
#  220,
#  234,
#  216,
#  228,
#  242,
#  242,
#  240,
#  240,
#  240,
#  228,
#  224,
#  214,
#  220,
#  216,
#  226,
#  244,
#  242,
#  228,
#  228,
#  246,
#  244,
#  232,
#  234,
#  242,
#  230,
#  246,
#  236,
#  260,
#  232,
#  218,
#  228,
#  212,
#  208,
#  216,
#  214,
#  220,
#  216,
#  198,
#  208,
#  214,
#  232,
#  220,
#  232,
#  218,
#  208,
#  224,
#  238,
#  232,
#  216,
#  230,
#  236,
#  218,
#  224,
#  228,
#  226,
#  222,
#  218,
#  218,
#  224,
#  216,
#  242,
#  230,
#  238,
#  236,
#  232,
#  220,
#  228,
#  208,
#  198,
#  198,
#  172,
#  182,
#  162,
#  190,
#  182,
#  196,
#  180,
#  214,
#  214,
#  206,
#  206,
#  232,
#  222,
#  214,
#  248,
#  238,
#  216,
#  196,
#  188,
#  182,
#  172,
#  200,
#  196,
#  196,
#  196,
#  196,
#  202,
#  220,
#  192,
#  200,
#  200,
#  188,
#  194,
#  192,
#  190,
#  192,
#  194,
#  218,
#  208,
#  192,
#  210,
#  190,
#  204,
#  206,
#  160,
#  186,
#  194,
#  204,
#  170,
#  196,
#  210,
#  194,
#  212,
#  216,
#  218,
#  214,
#  250,
#  204,
#  218,
#  192,
#  190,
#  204,
#  170,
#  174,
#  190,
#  180,
#  176,
#  160,
#  158,
#  158,
#  180,
#  180,
#  184,
#  176,
#  176,
#  178,
#  174,
#  188,
#  178,
#  182,
#  180,
#  162,
#  144,
#  154,
#  144,
#  142,
#  136,
#  132,
#  134,
#  140,
#  132,
#  136,
#  154,
#  168,
#  190,
#  190,
#  218,
#  214,
#  224,
#  204,
#  232,
#  194,
#  198,
#  204,
#  202,
#  182,
#  180,
#  172,
#  182,
#  180,
#  164,
#  162,
#  148,
#  156,
#  148,
#  128,
#  136,
#  132,
#  138,
#  154,
#  142,
#  152,
#  164,
#  172,
#  158,
#  164,
#  146,
#  150,
#  148,
#  148,
#  164,
#  178,
#  196,
#  194,
#  196,
#  192,
#  188,
#  196,
#  180,
#  176,
#  162,
#  160,
#  150,
#  158,
#  164,
#  166,
#  172,
#  162,
#  144,
#  144,
#  150,
#  142,
#  136,
#  136,
#  142,
#  120,
#  136,
#  124,
#  132,
#  112,
#  124,
#  120,
#  122,
#  138,
#  142,
#  148,
#  146,
#  144,
#  154,
#  146,
#  144,
#  160,
#  170,
#  164,
#  162,
#  144,
#  148,
#  130,
#  112,
#  126,
#  130,
#  126,
#  126,
#  132,
#  120,
#  118,
#  130,
#  128,
#  120,
#  142,
#  142,
#  148,
#  158,
#  158,
#  158,
#  160,
#  154,
#  174,
#  156,
#  160,
#  140,
#  126,
#  136,
#  130,
#  122,
#  116,
#  110,
#  112,
#  90,
#  84,
#  86,
#  82,
#  68,
#  70,
#  74,
#  82,
#  86,
#  92,
#  84,
#  88,
#  104,
#  114,
#  112,
#  120,
#  110,
#  100,
#  90,
#  98,
#  106,
#  104,
#  118,
#  120,
#  114,
#  112,
#  110,
#  92,
#  86,
#  84,
#  82,
#  66,
#  78,
#  66,
#  80,
#  86,
#  80,
#  88,
#  100,
#  98,
#  108,
#  104,
#  132,
#  128,
#  128,
#  112,
#  116,
#  100,
#  94,
#  72,
#  76,
#  80,
#  76,
#  68,
#  70,
#  72,
#  70,
#  68,
#  68,
#  72,
#  78,
#  74,
#  76,
#  80,
#  82,
#  80,
#  82,
#  76,
#  86,
#  88,
#  92,
#  92,
#  82,
#  98,
#  100,
#  110,
#  122,
#  118,
#  116,
#  104,
#  98,
#  106,
#  82,
#  78,
#  68,
#  78,
#  70,
#  82,
#  94,
#  108,
#  104,
#  124,
#  114,
#  82,
#  66,
#  58,
#  46,
#  38,
#  46,
#  34,
#  52,
#  40,
#  48,
#  42,
#  48,
#  44,
#  40,
#  52,
#  64,
#  80,
#  86,
#  76,
#  62,
#  60,
#  64,
#  66,
#  58,
#  58,
#  76,
#  62,
#  76,
#  70,
#  78,
#  82,
#  86,
#  86,
#  86,
#  94,
#  84,
#  90,
#  74,
#  72,
#  68,
#  74,
#  50,
#  56,
#  60,
#  46,
#  56,
#  60,
#  62,
#  64,
#  68,
#  78,
#  90,
#  102,
#  100,
#  100,
#  86,
#  80,
#  84,
#  68,
#  60,
#  62,
#  64,
#  54,
#  50,
#  38,
#  36,
#  44,
#  38,
#  40,
#  42,
#  38,
#  44,
#  46,
#  36,
#  58,
#  50,
#  56,
#  66,
#  68,
#  64,
#  68,
#  70,
#  74,
#  82,
#  76,
#  70,
#  56,
#  48,
#  48,
#  42,
#  52,
#  50,
#  54,
#  54,
#  54,
#  50,
#  42,
#  44,
#  44,
#  36,
#  36,
#  38,
#  38,
#  38,
#  48,
#  52,
#  48,
#  48,
#  58,
#  60,
#  64,
#  66,
#  66,
#  72,
#  74,
#  54,
#  60,
#  58,
#  50,
#  54,
#  54,
#  54,
#  50,
#  56,
#  58,
#  64,
#  66,
#  78,
#  56,
#  66,
#  60,
#  48,
#  44,
#  54,
#  50,
#  52,
#  62,
#  70,
#  66,
#  72,
#  72,
#  72,
#  70,
#  60,
#  64,
#  60,
#  52,
#  56,
#  58,
#  62,
#  66,
#  68,
#  70,
#  74,
#  68,
#  60,
#  50,
#  52,
#  38,
#  40,
#  44,
#  46,
#  42,
#  40,
#  32,
#  30,
#  38,
#  34,
#  30,
#  30,
#  24,
#  32,
#  34,
#  44,
#  56,
#  56,
#  66,
#  58,
#  56,
#  66,
#  70,
#  72,
#  66,
#  68,
#  64,
#  66,
#  76,
#  68,
#  58,
#  54,
#  46,
#  42,
#  36,
#  34,
#  36,
#  26,
#  30,
#  30,
#  32,
#  28,
#  30,
#  34,
#  28,
#  22,
#  18,
#  24,
#  22,
#  26,
#  22,
#  36,
#  38,
#  50,
#  52,
#  68,
#  74,
#  88,
#  88,
#  96,
#  104,
#  84,
#  68,
#  60,
#  56,
#  54,
#  32,
#  44,
#  30,
#  32,
#  28,
#  28,
#  32,
#  26,
#  30,
#  26,
#  34,
#  28,
#  28,
#  24,
#  26,
#  30,
#  26,
#  26,
#  32,
#  28,
#  36,
#  34,
#  42,
#  44,
#  48,
#  62,
#  46,
#  36,
#  22,
#  10,
#  12,
#  6,
#  16,
#  10,
#  10,
#  18,
#  20,
#  16,
#  18,
#  12,
#  10,
#  10,
#  16,
#  14,
#  10,
#  16,
#  16,
#  16,
#  14,
#  14,
#  18,
#  14,
#  8,
#  12,
#  12,
#  24,
#  20,
#  20,
#  26,
#  32,
#  50,
#  58,
#  62,
#  74,
#  58,
#  46,
#  38,
#  30,
#  34,
#  28,
#  20,
#  22,
#  26,
#  18,
#  30,
#  32,
#  28,
#  36,
#  34,
#  26,
#  26,
#  22,
#  24,
#  20,
#  22,
#  18,
#  20,
#  20,
#  20,
#  20,
#  22,
#  18,
#  24,
#  20,
#  16,
#  18,
#  20,
#  20,
#  16,
#  16,
#  14,
#  12,
#  18,
#  14,
#  18,
#  18,
#  16,
#  12,
#  8,
#  10,
#  12,
#  10,
#  14,
#  8,
#  10,
#  8,
#  4,
#  6,
#  12,
#  6,
#  16,
#  20,
#  34,
#  26,
#  22,
#  14,
#  16,
#  14,
#  22,
#  24,
#  34,
#  44,
#  46,
#  48,
#  40,
#  38,
#  28,
#  28,
#  26,
#  22,
#  20,
#  14,
#  14,
#  18,
#  12,
#  14,
#  14,
#  6,
#  4,
#  0,
#  4,
#  2,
#  4,
#  6,
#  8,
#  2,
#  2,
#  2,
#  4,
#  6,
#  0,
#  6,
#  8,
#  4,
#  8,
#  12,
#  14,
#  16,
#  18,
#  18,
#  18,
#  16,
#  14,
#  16,
#  18,
#  18,
#  18,
#  18,
#  24,
#  20,
#  20,
#  28,
#  26,
#  26,
#  32,
#  36,
#  42,
#  46,
#  52,
#  52,
#  40,
#  38,
#  34,
#  32,
#  24,
#  16,
#  22,
#  16,
#  16,
#  14,
#  16,
#  16,
#  18,
#  10,
#  16,
#  16,
#  18,
#  14,
#  16,
#  26,
#  26,
#  36,
#  44,
#  38,
#  30,
#  26,
#  30,
#  18,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  22,
#  20,
#  20,
#  22,
#  28,
#  26,
#  30,
#  26,
#  24,
#  32,
#  34,
#  40,
#  38,
#  40,
#  42,
#  40,
#  36,
#  36,
#  44,
#  46,
#  50,
#  58,
#  58,
#  64,
#  60,
#  58,
#  54,
#  54,
#  58,
#  54,
#  60,
#  54,
#  52,
#  54,
#  52,
#  50,
#  52,
#  52,
#  52,
#  54,
#  50,
#  56,
#  50,
#  52,
#  50,
#  50,
#  50,
#  48,
#  52,
#  48,
#  50,
#  52,
#  54,
#  52,
#  52,
#  46,
#  40,
#  38,
#  38,
#  38,
#  34,
#  36,
#  32,
#  36,
#  34,
#  32,
#  38,
#  36,
#  34,
#  34,
#  32,
#  34,
#  36,
#  34,
#  30,
#  36,
#  38,
#  30,
#  32,
#  32,
#  34,
#  30,
#  30,
#  34,
#  28,
#  28,
#  32,
#  30,
#  38,
#  30,
#  32,
#  32,
#  32,
#  30,
#  32]

# %%
print("訓練集：")
print("報酬率 vs rank")
plt.figure(1) 
plt.plot(sortPerformance50) # X:第n個EPISODE Y:第n個EPISODE的績效(performance)
plt.axhline(y = 0, color='r', linestyle='-') # 加上0%報酬率的線(紅線)
plt.axhline(y = training_set_buy_and_hold_return, color='g', linestyle='-') # 加上B&H報酬率的線(綠線)
plt.show()

print("交易次數 vs rank")
plt.figure(2)
plt.plot(sortTradetimes) # X:第n個EPISODE Y:第n個EPISODE的total reward
plt.show()
# Out:
# 訓練集：
# 報酬率 vs rank
# 交易次數 vs rank

# %%
    print("訓練集最後100個episode的平均報酬率為：" + str(np.mean(performance_list[EPISODES - 100 + 1 : EPISODES + 1])))
# Out:
# 訓練集最後100個episode的平均報酬率為：-0.04418042852897583

# %%
    #episode_index = range(1, EPISODES + 1)
    print("報酬率 vs episode")
    plt.figure(1) 
    plt.plot(performance_list) # X:第n個EPISODE Y:第n個EPISODE的績效(performance)
    plt.axhline(y = 0, color='r', linestyle='-') # 加上0%報酬率的線(紅線)
    plt.axhline(y = training_set_buy_and_hold_return, color='g', linestyle='-') # 加上B&H報酬率的線(綠線)
    plt.show()
    print("reward vs episode")
    plt.figure(2)
    plt.plot(reward_list) # X:第n個EPISODE Y:交易次數(第n個EPISODE一共發生close(selling stocks)的次數)
    plt.axhline(y = 0, color='r', linestyle='-') # 加上總獎勵為0的線(紅線)
    plt.show()
    print("交易次數 vs episode")
    plt.figure(3)
    plt.plot(transaction_times_list) # X:第n個EPISODE Y:第n個EPISODE的total reward
    plt.show()
    print("loss vs episode")
    plt.figure(4)
    plt.plot(loss_list) # Y:每一次訓練的loss值
    plt.show()
#     print("loss vs 後半段episode")
#     plt.figure(5)
#     plt.plot(loss_list[(EPISODES//2):EPISODES]) # Y:訓練後期每一次訓練的loss值
#     plt.show()
    print("交易次數 vs 報酬率")
    plt.figure(6)
    plt.scatter(performance_list, transaction_times_list) # Y:訓練後期每一次訓練的loss值
    plt.show()
    print("獎勵 vs 報酬率")
    plt.figure(7)
    plt.scatter(performance_list, reward_list) # Y:訓練後期每一次訓練的loss值
    plt.show()
    loss_list_new = [item.tolist() for item in loss_list[(EPISODES//2):]]
    print(np.mean(loss_list_new))
#     print(loss_list[(EPISODES//2):EPISODES])
# Out:
# 報酬率 vs episode
# reward vs episode
# 交易次數 vs episode
# loss vs episode
# 交易次數 vs 報酬率
# 獎勵 vs 報酬率
# 2.3707500185807363e-05

# %%
print(len(performance_list))
print(len(reward_list))
# Out:
# 1000
# 1000

# %%
    # 把param_dict中存的神經網路參數，按照實體報酬率的大小排序，並取排在前50名(暫定)的神經網路參數作為驗證時所用
#     top_param_num = 50 # 要取實體報酬率前幾名的神經網路參數
#     param_list = [] # 建立一個儲存神經網路參數的列表，之後用於驗證時用
    
#     for i in sorted(param_dict.items(), key=lambda d: d[0],reverse=True):
#         param_list.append(i[1])
#     param_list = param_list[:top_param_num]



    param_list50 = []

#     for idx, i in enumerate(sorted(performance_list, reverse=True)[:50]):

#         param_list50.append(param_list[idx])



    for p in sortPerformance50:
        trade_idx = sort_dict.get(p)
        print(trade_idx)
        param_list50.append(param_list[trade_idx])
# Out:
# 472
# 615
# 907
# 832
# 697
# 476
# 747
# 807
# 705
# 792
# 517
# 553
# 515
# 767
# 883
# 794
# 888
# 758
# 516
# 495
# 560
# 698
# 913
# 484
# 974
# 460
# 652
# 716
# 522
# 796
# 527
# 811
# 899
# 815
# 613
# 462
# 838
# 873
# 849
# 904
# 777
# 544
# 902
# 474
# 686
# 550
# 965
# 947
# 703
# 719

# %% [markdown]
# ## 存訓練集中表現較好的參數，作為下次訓練的起點

# %%
# # 排序後的第一個就是報酬率最高的，再從sort_dict取出他的index
# best_param_index_train = sort_dict.get(sortPerformance50[0]) 
# print(best_param_index)

# 儲存訓練集中最好的1組參數，因為是排序過的，第0個就是最好的
torch.save(param_list50[0], 'train_last_best_param_as_start.pkl')

# %%
# 儲存最好的50組參數
torch.save(param_list50, 'params_top50Return_Linear.pkl')
# param_list50 = torch.load('params_top50Return_Linear.pkl')

# %%
    # --------------- 驗證模型 ----------------
    # 取得驗證集
    csvfile_rows_validation_start_day = VALIDATION_START_DAY
    csvfile_rows_validation_start_day_index = -1
    
    csvfile_rows_validation_end_day = VALIDATION_END_DAY
    csvfile_rows_validation_end_day_index = -1
    
    for i in range(0, len(csvfile_rows)):
        if csvfile_rows[i][0] == csvfile_rows_validation_start_day:
            csvfile_rows_validation_start_day_index = i
        if csvfile_rows[i][0] == csvfile_rows_validation_end_day:
            csvfile_rows_validation_end_day_index = i
    
    csvfile_rows_validation = csvfile_rows[csvfile_rows_validation_start_day_index : csvfile_rows_validation_end_day_index + 1]

    # 對驗證集中連續型態的狀態變數資料做特徵縮放(feature scaling)
    csvfile_rows_validation = np.transpose(csvfile_rows_validation)
    csvfile_rows_validation = np.ndarray.tolist(csvfile_rows_validation)
    for i in csvfile_rows_validation[STATE_VARIABLE_START_INDEX : STATE_VARIABLE_CONTINUOUS_END_INDEX + 1]:
        for j in range(0, len(i)):
            i[j] = float(i[j])
    
#     # 錯誤的方法
#     for i in csvfile_rows_validation[STATE_VARIABLE_START_INDEX : STATE_VARIABLE_CONTINUOUS_END_INDEX + 1]:
#         status_variable_mean = statistics.mean(i)
#         status_variable_stdev = statistics.stdev(i)
#         for j in range(0, len(i)):
#             i[j] = (i[j] - status_variable_mean) / status_variable_stdev


#     for i in csvfile_rows_validation[STATE_VARIABLE_START_INDEX : STATE_VARIABLE_CONTINUOUS_END_INDEX + 1]:
# #         status_variable_mean = statistics.mean(i)
# #         status_variable_stdev = statistics.stdev(i)
#         for k in range(len(train_mean_list)):
#             mean=train_mean_list[k]
#             std=train_std_list[k]
#             for j in range(0, len(i)):
#                 i[j] = (i[j] - mean) / std
            
     # 錯誤的正確方法1       
    for index,i in enumerate(csvfile_rows_validation[STATE_VARIABLE_START_INDEX : STATE_VARIABLE_CONTINUOUS_END_INDEX + 1]):
#         status_variable_mean = statistics.mean(i)
#         status_variable_stdev = statistics.stdev(i)
#         train_mean_list = []
#     train_std_list = []
        for j in range(0, len(i)):
            i[j] = (i[j] - train_mean_list[index]) / train_std_list[index]
    
    # 錯誤的正確方法2
#     for i in range(len(csvfile_rows_validation[STATE_VARIABLE_START_INDEX : STATE_VARIABLE_CONTINUOUS_END_INDEX + 1])):
# #         status_variable_mean = statistics.mean(i)
# #         status_variable_stdev = statistics.stdev(i)
# #         train_mean_list = []
# #     train_std_list = []
#         for j in range(0, len(csvfile_rows_validation[STATE_VARIABLE_START_INDEX : STATE_VARIABLE_CONTINUOUS_END_INDEX + 1][i])):
#             csvfile_rows_validation[STATE_VARIABLE_START_INDEX : STATE_VARIABLE_CONTINUOUS_END_INDEX + 1][i][j] = (csvfile_rows_validation[STATE_VARIABLE_START_INDEX : STATE_VARIABLE_CONTINUOUS_END_INDEX + 1][1][j] - train_mean_list[i]) / train_std_list[i]
    
    csvfile_rows_validation = np.transpose(csvfile_rows_validation)
    csvfile_rows_validation = np.ndarray.tolist(csvfile_rows_validation)
    for i in csvfile_rows_validation:
        for j in range(1, N_COLUMNS):
            if i[j] != '' and j in [1,2,3] or j in range(STATE_VARIABLE_DISCRETE_START_INDEX, N_COLUMNS):
                i[j] = int(i[j])
            elif i[j] != '':
                i[j] = float(i[j])
    
    csvfile.close()
    
    '''
    驗證集的敘述統計
    '''
    csvfile_df = pd.read_csv("D:/專案/資料集/twse0050_ver10.csv")
    valid_df = pd.DataFrame(csvfile_rows_validation[STATE_VARIABLE_START_INDEX : 
                                                    STATE_VARIABLE_CONTINUOUS_END_INDEX + 1], columns = csvfile_df.columns)
    print("驗證集的敘述統計：")
    print(valid_df.describe())
    '''
    驗證集的敘述統計
    '''
    
    #print(csvfile_rows_validation[0:5])
    
    # 建立紀錄performance和transaction times的列表(list),之後畫圖會用到
    val_performance_list = []
    val_transaction_times_list = []
    
    episode_start_day_index = 1 # 挑選驗證集第二個交易日為episode開始的日期(因為會用到第一個交易日的狀態變數資料，所以要從第二天開始)
    episode_start_day = csvfile_rows_validation[episode_start_day_index][0]

    episode_end_day_index = len(csvfile_rows_validation) - 1 # 挑選驗證集倒數第一個交易日為episode結束的日期
    episode_end_day = csvfile_rows_validation[episode_end_day_index][0]
    
    validation_set_buy_and_hold_return = ((csvfile_rows_validation[len(csvfile_rows_validation) - 1][OPENING_PRICE_INDEX]
               - csvfile_rows_validation[0][OPENING_PRICE_INDEX]) / csvfile_rows_validation[0][OPENING_PRICE_INDEX])
    print("在驗證集中，使用B&H的報酬率為：", validation_set_buy_and_hold_return)
    
    # 儲存測試集所需要的agents
    test_agents = {}
    
    # 驗證時agent隨機選取行動的機率為0(agent完全照現在的參數選取動作)
    dqn.epsilon = 0
    net1 = Net()
    
    force_sell_counter = 0 # 強制賣掉的參數組數
    
    # ...
    for i_episode in range(len(param_list50)):
        
        print("第{}組參數/共{}組參數".format(str(i_episode + 1), str(len(param_list50))))

        # 把之前紀錄的神經網路參數複製到神經網路中，以驗證在這個參數下agent在股市交易的表現
        dqn.copy_params(param_list50[i_episode])
        net1.load_state_dict(param_list50[i_episode])

        # 重新一個episode時把所有驗證集中的資產持有狀態全部設為0 (開始投資之前不會有資料的資產持有狀態為1，因為根本還沒有開始買股票)
        for i in csvfile_rows_validation:
            i[CURRENT_POSITION_INDEX] = 0

        state = csvfile_rows_validation[episode_start_day_index - 1][STATE_VARIABLE_START_INDEX:] # 根據日期取得狀態變數
        np.asarray(state, dtype = float)
        state = np.reshape(state, [1, N_STATES]) # 為了讓狀態可以餵進神經網路所做的維度調整

        initial_principal = 100000 # 本金
        cash_hold = initial_principal # agent目前「實際」持有的現金
        transaction_cost_rate = 0.001425 # 交易成本(手續費)比率
        number_of_shares_held = 0 # 持有股數(每一次EPISODE開始前都要歸零)

        done = False # 是否結束該EPISODE(結束條件為在持有股票的狀態下選擇賣掉股票的行動)
        performance = 0 # 該EPISODE「實際」的投資報酬率
        transaction_times = 0 # 該EPISODE發生的交易次數(買和賣皆算進行一次交易)
        
        buy_price = 0 # 買入股票的價格
        
        profit = 0 # 賺到的錢，不再拿去投資

        for day in range(episode_start_day_index, episode_end_day_index + 1):

            # 選擇行動
            action = net1.choose_action(state)

            # 當EPISODE進行到倒數第一天時就要強制結束該EPISODE，因為後面沒資料了
            if day == (episode_end_day_index):
                done = True
                if (csvfile_rows_validation[day - 1][CURRENT_POSITION_INDEX] == 0): 
                    # 如果t-1期的agent之前持有的是現金，則繼續持有現金(wait)
                    action = 0
                    
                else:
                    # 如果agent之前持有的是股票，則強制賣出股票(sell)
                    action = 1 
                    
                    # 根據公式計算出agent在賣出股票後將會持有的現金
                    cash_hold = (number_of_shares_held * csvfile_rows_validation[day][CLOSING_PRICE_INDEX] 
                                 * (1 - transaction_cost_rate))

                    # 每賣出一次股票，該EPISODE的交易次數就增加一次
                    transaction_times += 1 
                    number_of_shares_held = 0
                    print("                     第{}組參數有在最後一天強制賣掉".format(i_episode + 1))
                    force_sell_counter += 1

            # 根據行動計算獎勵
            if csvfile_rows_validation[day - 1][CURRENT_POSITION_INDEX] == 0 and done == False:

                if action == 1: # 如果t-1期的當前資產部位為持有現金(current position = 0)，且行動為1(action = 1)，則買入股票(buy)
                    
                    # 買入股票的價格為t期的開盤價
                    buy_price = csvfile_rows_validation[day][CLOSING_PRICE_INDEX] 
                    
                    # 根據公式計算出agent在買入股票後將會持有的股數
                    number_of_shares_held = cash_hold  / (buy_price * (1 + transaction_cost_rate)) 
                    
                    # 買入股票後，t期的「資產當前部位」將設為1
                    csvfile_rows_validation[day][CURRENT_POSITION_INDEX] = 1
                    
                    # 由於將所有的現金拿去買股票，所以之後agent持有的現金為0
                    cash_hold = 0 
                    
                    # 每買入一次股票，該EPISODE的交易次數就增加一次
                    transaction_times += 1
                    print("買")

            elif csvfile_rows_validation[day - 1][CURRENT_POSITION_INDEX] == 1 and done == False:

                if action == 1: # 如果t-1期的當前資產部位為持有股票(current position = 1)，且行動為1(action = 1)，則賣出股票(sell)
   
                    # 根據公式計算出agent在賣出股票後將會持有的現金
                    cash_hold = (number_of_shares_held * csvfile_rows_validation[day][CLOSING_PRICE_INDEX] 
                                 * (1 - transaction_cost_rate))
                    
                    # 每賣出一次股票，該EPISODE的交易次數就增加一次
                    transaction_times += 1 
                    number_of_shares_held = 0
                    
                    # 若賺的錢超過本金，只拿本金再投資
#                     if cash_hold > initial_principal:
#                         profit += cash_hold - initial_principal
#                         cash_hold = initial_principal
                    print("賣")

                elif action == 0: # 如果當前資產部位為持有股票(current position = 1)，且行動為0(action = 0)，則繼續持有股票(hold)
                    
                    # 由於繼續持有股票，t期的「資產當前部位」將設為1
                    csvfile_rows_validation[day][CURRENT_POSITION_INDEX] = 1
                    print("持有")
            
            # 取得下一個狀態
            next_state = csvfile_rows_validation[day][STATE_VARIABLE_START_INDEX:]

            # 為了讓下一個狀態可以餵進神經網路所做的維度調整
            next_state = np.reshape(next_state, [1, N_STATES]) 
            
            # 更新狀態和股票持有的狀態
            state = next_state         
            
            # 每個episode結束時的處理事項
            if done: 
                # 計算實體報酬率
                performance = (cash_hold - initial_principal + profit) / initial_principal
                
                # 紀錄該episode的相關資訊                
                val_performance_list.append(performance)
                val_transaction_times_list.append(transaction_times)
                loss_list.append(dqn.loss)
                
                # 印出該episode的相關資訊
                print("該episode開始的日期為:", episode_start_day)
                print("該episode結束的日期為:", episode_end_day)
                print('該episode最後持有的現金為：', cash_hold + profit)
                print('該episode的實際報酬率(績效)為：', performance)
                print('該episode的交易次數為(買入和賣出股票的次數)：', transaction_times)
                print("該episode已賺得利潤為：", profit)
                print() # 空一行做為分隔
                
                # 將每個模型與實際報酬率都先儲存起來之後測試集要用
                test_agents[performance] = param_list50[i_episode]
print("被強制賣掉的參數組數為", force_sell_counter)
# Out:
# 驗證集的敘述統計：
#                成交股數          成交金額         成交筆數        開盤價        最高價  \
# count  2.400000e+01  2.400000e+01    24.000000  24.000000  24.000000
# mean   1.203233e+07  7.042726e+08  3748.291667  58.558333  59.029167
# std    5.049799e+06  2.918665e+08  1577.110938   1.764916   1.757092
# min    4.584277e+06  2.721352e+08  1464.000000  55.900000  56.300000
# 25%    7.916787e+06  4.693365e+08  2606.250000  57.000000  57.412500
# 50%    1.148342e+07  7.007362e+08  3538.500000  58.650000  59.175000
# 75%    1.469113e+07  8.477530e+08  4491.250000  60.450000  60.637500
# max    2.268837e+07  1.270702e+09  7993.000000  61.000000  61.600000
#
#              最低價        收盤價       漲跌價差     收盤價MA5    收盤價MA10  ...     4     5  \
# count  24.000000  24.000000  24.000000  24.000000  24.000000  ...  24.0  24.0
# mean   58.204167  58.710417   0.183333  -1.736203  -1.823022  ...   0.0   0.0
# [[[[-0.00122956 -0.02589072]]]]
# [[[[-0.00241337 -0.03913827]]]]
# [[[[-0.00326739 -0.05065393]]]]
# [[[[-0.00306747 -0.04833318]]]]
# [[[[-0.00316456 -0.05012306]]]]
# [[[[-0.00311952 -0.04868472]]]]
# [[[[-0.00304543 -0.04706052]]]]
# [[[[-0.00246959 -0.04243895]]]]
# [[[[-0.00233452 -0.04149126]]]]
# [[[[-0.00229674 -0.0416384 ]]]]
# [[[[-0.00232792 -0.04120459]]]]
# [[[[-0.00230219 -0.0419299 ]]]]
# [[[[-0.002797   -0.04671963]]]]
# [[[[-0.00229104 -0.04226753]]]]
# [[[[-0.00180244 -0.03524929]]]]
# [[[[-0.00119283 -0.02813335]]]]
# [[[[-0.00029711 -0.01841551]]]]
# [[[[ 0.00047956 -0.01004367]]]]
# [[[[0.00143089 0.00202947]]]]
# 買
# [[[[0.0012231  0.00153294]]]]
# 賣
# [[[[0.00193078 0.00877867]]]]
# 買
# [[[[0.00197508 0.00731811]]]]
#                      第50組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/1/5
# 該episode結束的日期為: 2016/3/31
# 該episode最後持有的現金為： 100932.88772783203
# 該episode的實際報酬率(績效)為： 0.009328877278320288
# 該episode的交易次數為(買入和賣出股票的次數)： 6
# 該episode已賺得利潤為： 0
#
# 被強制賣掉的參數組數為 23

# %%
    print("驗證集的平均報酬率為：" + str(np.mean(val_performance_list)))
    print("驗證集的平均交易次數為：" + str(np.mean(val_transaction_times_list)))
# Out:
# 驗證集的平均報酬率為：0.03871160282854902
# 驗證集的平均交易次數為：4.32

# %%
# # 驗證集排名前50 畫 報酬率 VS rank、交易次數 VS rank
# # 用字典存報酬率和idx
# sort_dict_valid = {}
# for idx, p in enumerate(val_performance_list):
#     sort_dict_valid[p] = idx
# # print(sortPerformance)
# sortPerformance = sorted(val_performance_list, reverse = True)
# sortPerformance50 = sortPerformance[:50]
# # len(sortPerformance50)

# # 交易次數是報酬率前50的交易次數
# # 再從以排序的報酬率列表中，用報酬率為key，抓原始報酬率列表的index(第幾個episode)
# # 再用這個index丟正確的交易次數進去sortTradetimes
# sortTradetimes = []
# for p in sortPerformance50:
#     trade_idx = sort_dict_valid.get(p)
#     sortTradetimes.append(val_transaction_times_list[trade_idx])
    
# print(sortTradetimes)

# %%
print("驗證集：")
print("報酬率 vs rank")
plt.figure(1) 
plt.plot(val_performance_list) # X:第n個EPISODE Y:第n個EPISODE的績效(performance)
plt.axhline(y = 0, color='r', linestyle='-') # 加上0%報酬率的線(紅線)
plt.axhline(y = validation_set_buy_and_hold_return, color='g', linestyle='-') # 加上B&H報酬率的線(綠線)
plt.show()

print("交易次數 vs rank")
plt.figure(2)
plt.plot(val_transaction_times_list) # X:第n個EPISODE Y:第n個EPISODE的total reward
plt.show()
# Out:
# 驗證集：
# 報酬率 vs rank
# 交易次數 vs rank

# %%
    plt.figure(5) 
    plt.plot(val_performance_list) # X:第n個EPISODE Y:第n個EPISODE的報酬率(performance)
    plt.axhline(y = 0, color='r', linestyle='-') # 加上0%報酬率的線(紅線)
    plt.axhline(y = validation_set_buy_and_hold_return, color='g', linestyle='-') # 加上B&H報酬率的線(綠線)

# %%
#取出最好的 n 個agent，每個各握有25000元 從2017/06/30到2017/12/29實際再去玩一次
test_param_list = [] # 儲存 n 個模型參數
Test_AGENTS_NUM = 50
for i in sorted(test_agents.items(), key=lambda d: d[0],reverse=True):
    test_param_list.append(i[1])
test_param_list = test_param_list[:Test_AGENTS_NUM]

# %%
    # --------------- 測試模型 ----------------
    # 取得測試集
    csvfile_rows_test_start_day = TEST_START_DAY
    csvfile_rows_test_start_day_index = -1
    
    csvfile_rows_test_end_day = TEST_END_DAY
    csvfile_rows_test_end_day_index = -1
    
    for i in range(0, len(csvfile_rows)):
        if csvfile_rows[i][0] == csvfile_rows_test_start_day:
            csvfile_rows_test_start_day_index = i
        if csvfile_rows[i][0] == csvfile_rows_test_end_day:
            csvfile_rows_test_end_day_index = i
    
    csvfile_rows_test = csvfile_rows[csvfile_rows_test_start_day_index : csvfile_rows_test_end_day_index + 1]

    # 對測試集中連續型態的狀態變數資料做特徵縮放(feature scaling)
    csvfile_rows_test = np.transpose(csvfile_rows_test)
    csvfile_rows_test = np.ndarray.tolist(csvfile_rows_test)
    for i in csvfile_rows_test[STATE_VARIABLE_START_INDEX : STATE_VARIABLE_CONTINUOUS_END_INDEX + 1]:
        for j in range(0, len(i)):
            i[j] = float(i[j])
    
    for index, i in enumerate(csvfile_rows_test[STATE_VARIABLE_START_INDEX : STATE_VARIABLE_CONTINUOUS_END_INDEX + 1]):
        for j in range(0, len(i)):
            i[j] = (i[j] - train_mean_list[index]) / train_std_list[index]
    
    csvfile_rows_test = np.transpose(csvfile_rows_test)
    csvfile_rows_test = np.ndarray.tolist(csvfile_rows_test)
    for i in csvfile_rows_test:
        for j in range(1, N_COLUMNS):
            if i[j] != '' and j in [1,2,3] or j in range(STATE_VARIABLE_DISCRETE_START_INDEX, N_COLUMNS):
                i[j] = int(i[j])
            elif i[j] != '':
                i[j] = float(i[j])

    
    csvfile.close()
                
    #print(csvfile_rows_test[0:5])
    
    # 建立紀錄performance和transaction times的列表(list),之後畫圖會用到
    #performance_list = []
    #transaction_times_list = []
    
    #紀錄所有agent的報酬總和
    performance_total = 0
    
    episode_start_day_index = 1 # 挑選測試集第二個交易日為episode開始的日期(因為會用到第一個交易日的狀態變數資料，所以要從第二天開始)
    episode_start_day = csvfile_rows_test[episode_start_day_index][0]

    episode_end_day_index = len(csvfile_rows_test) - 1 # 挑選測試集倒數第一個交易日為episode結束的日期
    episode_end_day = csvfile_rows_test[episode_end_day_index][0]
    
    test_set_buy_and_hold_return = ((csvfile_rows_test[len(csvfile_rows_test) - 1][OPENING_PRICE_INDEX]
               - csvfile_rows_test[0][OPENING_PRICE_INDEX]) / csvfile_rows_test[0][OPENING_PRICE_INDEX])
    print("在測試集中，使用B&H的報酬率為：", test_set_buy_and_hold_return)
    
    # 測試時agent隨機選取行動的機率為0(agent完全照現在的參數選取動作)
    dqn.epsilon = 0
    
    performance_list_test = []
    transaction_times_list_test = []
    
    force_sell_counter = 0 # 強制賣掉的參數組數
    
    # ...
    for i_episode in range(len(param_list50)):
        
        print("第{}組參數/共{}組參數".format(str(i_episode + 1), str(len(param_list50))))

        # 把之前紀錄的神經網路參數複製到神經網路中，以測試在這個參數下agent在股市交易的表現
        dqn.copy_params(param_list50[i_episode])

        # 重新一個episode時把所有測試集中的資產持有狀態全部設為0 (開始投資之前不會有資料的資產持有狀態為1，因為根本還沒有開始買股票)
        for i in csvfile_rows_test:
            i[CURRENT_POSITION_INDEX] = 0

        state = csvfile_rows_test[episode_start_day_index - 1][STATE_VARIABLE_START_INDEX:] # 根據日期取得狀態變數
        np.asarray(state, dtype = float)
        state = np.reshape(state, [1, N_STATES]) # 為了讓狀態可以餵進神經網路所做的維度調整

        initial_principal = 100000/Test_AGENTS_NUM # 本金
        cash_hold = initial_principal # agent目前「實際」持有的現金
        transaction_cost_rate = 0.001425 # 交易成本(手續費)比率
        number_of_shares_held = 0 # 持有股數(每一次EPISODE開始前都要歸零)

        done = False # 是否結束該EPISODE(結束條件為在持有股票的狀態下選擇賣掉股票的行動)
        performance = 0 # 該EPISODE「實際」的投資報酬率
        transaction_times = 0 # 該EPISODE發生的交易次數(買和賣皆算進行一次交易)
        
        buy_price = 0 # 買入股票的價格
        
        profit = 0 # 賺到的錢，不再拿去投資

        for day in range(episode_start_day_index, episode_end_day_index + 1):

            # 選擇行動
            action = dqn.choose_action(state)

            # 當EPISODE進行到倒數第一天時就要強制結束該EPISODE，因為後面沒資料了
            if day == (episode_end_day_index):
                done = True
                if (csvfile_rows_test[day - 1][CURRENT_POSITION_INDEX] == 0): 
                    # 如果t-1期的agent之前持有的是現金，則繼續持有現金(wait)
                    action = 0
                    
                else:
                    # 如果agent之前持有的是股票，則強制賣出股票(sell)
                    action = 1 
                    
                    # 根據公式計算出agent在賣出股票後將會持有的現金
                    cash_hold = (number_of_shares_held * csvfile_rows_test[day][CLOSING_PRICE_INDEX] 
                                 * (1 - transaction_cost_rate))

                    # 每賣出一次股票，該EPISODE的交易次數就增加一次
                    transaction_times += 1 
                    number_of_shares_held = 0
                    print("                     第{}組參數有在最後一天強制賣掉".format(i_episode + 1))
                    force_sell_counter += 1

            # 根據行動計算獎勵
            if csvfile_rows_test[day - 1][CURRENT_POSITION_INDEX] == 0 and done == False:

                if action == 1: # 如果t-1期的當前資產部位為持有現金(current position = 0)，且行動為1(action = 1)，則買入股票(buy)
                    
                    # 買入股票的價格為t期的開盤價
                    buy_price = csvfile_rows_test[day][CLOSING_PRICE_INDEX] 
                    
                    # 根據公式計算出agent在買入股票後將會持有的股數
                    number_of_shares_held = cash_hold  / (buy_price * (1 + transaction_cost_rate)) 
                    
                    # 買入股票後，t期的「資產當前部位」將設為1
                    csvfile_rows_test[day][CURRENT_POSITION_INDEX] = 1
                    
                    # 由於將所有的現金拿去買股票，所以之後agent持有的現金為0
                    cash_hold = 0 
                    
                    # 每買入一次股票，該EPISODE的交易次數就增加一次
                    transaction_times += 1

            elif csvfile_rows_test[day - 1][CURRENT_POSITION_INDEX] == 1 and done == False:

                if action == 1: # 如果t-1期的當前資產部位為持有股票(current position = 1)，且行動為1(action = 1)，則賣出股票(sell)
   
                    # 根據公式計算出agent在賣出股票後將會持有的現金
                    cash_hold = (number_of_shares_held * csvfile_rows_test[day][CLOSING_PRICE_INDEX] 
                                 * (1 - transaction_cost_rate))
                    
                    # 每賣出一次股票，該EPISODE的交易次數就增加一次
                    transaction_times += 1 
                    number_of_shares_held = 0
                    
                    # 若賺的錢超過本金，只拿本金再投資
#                     if cash_hold > initial_principal:
#                         profit += cash_hold - initial_principal
#                         cash_hold = initial_principal

                elif action == 0: # 如果當前資產部位為持有股票(current position = 1)，且行動為0(action = 0)，則繼續持有股票(hold)
                    
                    # 由於繼續持有股票，t期的「資產當前部位」將設為1
                    csvfile_rows_test[day][CURRENT_POSITION_INDEX] = 1
            
            # 取得下一個狀態
            next_state = csvfile_rows_test[day][STATE_VARIABLE_START_INDEX:]

            # 為了讓下一個狀態可以餵進神經網路所做的維度調整
            next_state = np.reshape(next_state, [1, N_STATES]) 
            
            # 更新狀態和股票持有的狀態
            state = next_state         
            
            # 每個episode結束時的處理事項
            
            if done: 
                # 計算實體報酬率
                performance = (cash_hold - initial_principal + profit) / initial_principal
                
                # 紀錄該episode的相關資訊                
                performance_list_test.append(performance)
                transaction_times_list_test.append(transaction_times)
                loss_list.append(dqn.loss)
                performance_total += cash_hold
                
                # 印出該episode的相關資訊
                print("該episode開始的日期為:", episode_start_day)
                print("該episode結束的日期為:", episode_end_day)
                print('該episode最後持有的現金為：', cash_hold + profit)
                print('該episode的實際報酬率(績效)為：', performance)
                print('該episode的交易次數為(買入和賣出股票的次數)：', transaction_times)
                print("該episode已賺得利潤為：", profit)
                print() # 空一行做為分隔
print("被強制賣掉的參數組數為", force_sell_counter)
# Out:
# 在測試集中，使用B&H的報酬率為： 0.014007782101167404
# 第1組參數/共50組參數
#                      第1組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1977.9503913182004
# 該episode的實際報酬率(績效)為： -0.011024804340899778
# 該episode的交易次數為(買入和賣出股票的次數)： 40
# 該episode已賺得利潤為： 0
#
# 第2組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1921.2616826956994
# 該episode的實際報酬率(績效)為： -0.03936915865215031
# 該episode的交易次數為(買入和賣出股票的次數)： 46
# 該episode已賺得利潤為： 0
#
# 第3組參數/共50組參數
#                      第3組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 2107.681827306586
# 該episode的實際報酬率(績效)為： 0.053840913653293
# 該episode的交易次數為(買入和賣出股票的次數)： 20
# 該episode已賺得利潤為： 0
#
# 第4組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 2016.8830279775916
# 該episode的實際報酬率(績效)為： 0.008441513988795805
# 該episode的交易次數為(買入和賣出股票的次數)： 32
# 該episode已賺得利潤為： 0
#
# 第5組參數/共50組參數
#                      第5組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1876.5553548521332
# 該episode的實際報酬率(績效)為： -0.06172232257393341
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 第6組參數/共50組參數
#                      第6組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1977.9503913182004
# 該episode的實際報酬率(績效)為： -0.011024804340899778
# 該episode的交易次數為(買入和賣出股票的次數)： 40
# 該episode已賺得利潤為： 0
#
# 第7組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1894.3978782300383
# 該episode的實際報酬率(績效)為： -0.05280106088498087
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 第8組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1939.8455587686824
# 該episode的實際報酬率(績效)為： -0.030077220615658803
# 該episode的交易次數為(買入和賣出股票的次數)： 38
# 該episode已賺得利潤為： 0
#
# 第9組參數/共50組參數
#                      第9組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1876.5553548521332
# 該episode的實際報酬率(績效)為： -0.06172232257393341
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 第10組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1939.8455587686824
# 該episode的實際報酬率(績效)為： -0.030077220615658803
# 該episode的交易次數為(買入和賣出股票的次數)： 38
# 該episode已賺得利潤為： 0
#
# 第11組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1894.3978782300383
# 該episode的實際報酬率(績效)為： -0.05280106088498087
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 第12組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1894.3978782300383
# 該episode的實際報酬率(績效)為： -0.05280106088498087
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 第13組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1894.90506411722
# 該episode的實際報酬率(績效)為： -0.05254746794138998
# 該episode的交易次數為(買入和賣出股票的次數)： 44
# 該episode已賺得利潤為： 0
#
# 第14組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1987.0067822378046
# 該episode的實際報酬率(績效)為： -0.0064966088810977
# 該episode的交易次數為(買入和賣出股票的次數)： 38
# 該episode已賺得利潤為： 0
#
# 第15組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1934.1407448446055
# 該episode的實際報酬率(績效)為： -0.03292962757769726
# 該episode的交易次數為(買入和賣出股票的次數)： 16
# 該episode已賺得利潤為： 0
#
# 第16組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1939.8455587686824
# 該episode的實際報酬率(績效)為： -0.030077220615658803
# 該episode的交易次數為(買入和賣出股票的次數)： 38
# 該episode已賺得利潤為： 0
#
# 第17組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1934.1407448446055
# 該episode的實際報酬率(績效)為： -0.03292962757769726
# 該episode的交易次數為(買入和賣出股票的次數)： 16
# 該episode已賺得利潤為： 0
#
# 第18組參數/共50組參數
#                      第18組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1892.6655810619975
# 該episode的實際報酬率(績效)為： -0.05366720946900125
# 該episode的交易次數為(買入和賣出股票的次數)： 40
# 該episode已賺得利潤為： 0
#
# 第19組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1894.3978782300383
# 該episode的實際報酬率(績效)為： -0.05280106088498087
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 第20組參數/共50組參數
#                      第20組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1876.5553548521332
# 該episode的實際報酬率(績效)為： -0.06172232257393341
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 第21組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1894.3978782300383
# 該episode的實際報酬率(績效)為： -0.05280106088498087
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 第22組參數/共50組參數
#                      第22組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1876.5553548521332
# 該episode的實際報酬率(績效)為： -0.06172232257393341
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 第23組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 2091.068589637339
# 該episode的實際報酬率(績效)為： 0.04553429481866942
# 該episode的交易次數為(買入和賣出股票的次數)： 24
# 該episode已賺得利潤為： 0
#
# 第24組參數/共50組參數
#                      第24組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1876.5553548521332
# 該episode的實際報酬率(績效)為： -0.06172232257393341
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 第25組參數/共50組參數
#                      第25組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1972.813279346797
# 該episode的實際報酬率(績效)為： -0.013593360326601555
# 該episode的交易次數為(買入和賣出股票的次數)： 26
# 該episode已賺得利潤為： 0
#
# 第26組參數/共50組參數
#                      第26組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1876.5553548521332
# 該episode的實際報酬率(績效)為： -0.06172232257393341
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 第27組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1894.3978782300383
# 該episode的實際報酬率(績效)為： -0.05280106088498087
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 第28組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1894.3978782300383
# 該episode的實際報酬率(績效)為： -0.05280106088498087
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 第29組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1894.3978782300383
# 該episode的實際報酬率(績效)為： -0.05280106088498087
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 第30組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1939.8455587686824
# 該episode的實際報酬率(績效)為： -0.030077220615658803
# 該episode的交易次數為(買入和賣出股票的次數)： 38
# 該episode已賺得利潤為： 0
#
# 第31組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1894.3978782300383
# 該episode的實際報酬率(績效)為： -0.05280106088498087
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 第32組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1939.8455587686824
# 該episode的實際報酬率(績效)為： -0.030077220615658803
# 該episode的交易次數為(買入和賣出股票的次數)： 38
# 該episode已賺得利潤為： 0
#
# 第33組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 2002.2800937852994
# 該episode的實際報酬率(績效)為： 0.001140046892649707
# 該episode的交易次數為(買入和賣出股票的次數)： 18
# 該episode已賺得利潤為： 0
#
# 第34組參數/共50組參數
#                      第34組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1916.106287315454
# 該episode的實際報酬率(績效)為： -0.041946856342273006
# 該episode的交易次數為(買入和賣出股票的次數)： 40
# 該episode已賺得利潤為： 0
#
# 第35組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1921.2616826956994
# 該episode的實際報酬率(績效)為： -0.03936915865215031
# 該episode的交易次數為(買入和賣出股票的次數)： 46
# 該episode已賺得利潤為： 0
#
# 第36組參數/共50組參數
#                      第36組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1876.5553548521332
# 該episode的實際報酬率(績效)為： -0.06172232257393341
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 第37組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1989.08917865675
# 該episode的實際報酬率(績效)為： -0.005455410671625032
# 該episode的交易次數為(買入和賣出股票的次數)： 24
# 該episode已賺得利潤為： 0
#
# 第38組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 2066.624460969263
# 該episode的實際報酬率(績效)為： 0.03331223048463153
# 該episode的交易次數為(買入和賣出股票的次數)： 24
# 該episode已賺得利潤為： 0
#
# 第39組參數/共50組參數
#                      第39組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1985.5733244899702
# 該episode的實際報酬率(績效)為： -0.007213337755014891
# 該episode的交易次數為(買入和賣出股票的次數)： 20
# 該episode已賺得利潤為： 0
#
# 第40組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 2002.2800937852994
# 該episode的實際報酬率(績效)為： 0.001140046892649707
# 該episode的交易次數為(買入和賣出股票的次數)： 18
# 該episode已賺得利潤為： 0
#
# 第41組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1987.0067822378046
# 該episode的實際報酬率(績效)為： -0.0064966088810977
# 該episode的交易次數為(買入和賣出股票的次數)： 38
# 該episode已賺得利潤為： 0
#
# 第42組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1894.90506411722
# 該episode的實際報酬率(績效)為： -0.05254746794138998
# 該episode的交易次數為(買入和賣出股票的次數)： 44
# 該episode已賺得利潤為： 0
#
# 第43組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 2002.2800937852994
# 該episode的實際報酬率(績效)為： 0.001140046892649707
# 該episode的交易次數為(買入和賣出股票的次數)： 18
# 該episode已賺得利潤為： 0
#
# 第44組參數/共50組參數
#                      第44組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1977.9503913182004
# 該episode的實際報酬率(績效)為： -0.011024804340899778
# 該episode的交易次數為(買入和賣出股票的次數)： 40
# 該episode已賺得利潤為： 0
#
# 第45組參數/共50組參數
#                      第45組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1876.5553548521332
# 該episode的實際報酬率(績效)為： -0.06172232257393341
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 第46組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1894.3978782300383
# 該episode的實際報酬率(績效)為： -0.05280106088498087
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 第47組參數/共50組參數
#                      第47組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1972.813279346797
# 該episode的實際報酬率(績效)為： -0.013593360326601555
# 該episode的交易次數為(買入和賣出股票的次數)： 26
# 該episode已賺得利潤為： 0
#
# 第48組參數/共50組參數
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1973.5666290206777
# 該episode的實際報酬率(績效)為： -0.013216685489661132
# 該episode的交易次數為(買入和賣出股票的次數)： 28
# 該episode已賺得利潤為： 0
#
# 第49組參數/共50組參數
#                      第49組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1876.5553548521332
# 該episode的實際報酬率(績效)為： -0.06172232257393341
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 第50組參數/共50組參數
#                      第50組參數有在最後一天強制賣掉
# 該episode開始的日期為: 2016/4/6
# 該episode結束的日期為: 2016/6/30
# 該episode最後持有的現金為： 1876.5553548521332
# 該episode的實際報酬率(績效)為： -0.06172232257393341
# 該episode的交易次數為(買入和賣出股票的次數)： 42
# 該episode已賺得利潤為： 0
#
# 被強制賣掉的參數組數為 19

# %%
print('總金額為: %f' % performance_total)
preformance_ratio = ((performance_total - initial_principal*Test_AGENTS_NUM) / (initial_principal*Test_AGENTS_NUM))
print('實際報酬率(績效)為: %f' % preformance_ratio)
# Out:
# 總金額為: 96808.965593
# 實際報酬率(績效)為: -0.031910

# %%
# # 測試集排名前50 畫 報酬率 VS rank、交易次數 VS rank
# # 用字典存報酬率和idx
# sort_dict_test = {}
# for idx, p in enumerate(performance_list_test):
#     sort_dict_test[p] = idx
# # print(sortPerformance)
# sortPerformance = sorted(performance_list_test, reverse = True)
# sortPerformance50 = sortPerformance[:50]
# # print(len(sortPerformance50))

# # 交易次數是報酬率前50的交易次數
# # 再從以排序的報酬率列表中，用報酬率為key，抓原始報酬率列表的index(第幾個episode)
# # 再用這個index丟正確的交易次數進去sortTradetimes
# sortTradetimes = []
# for p in sortPerformance50:
#     trade_idx = sort_dict_test.get(p)
#     sortTradetimes.append(transaction_times_list_test[trade_idx])
    
# print(sortTradetimes)

# %%
print("測試集：")
print("報酬率 vs rank")
plt.figure(1) 
plt.plot(performance_list_test) # X:第n個EPISODE Y:第n個EPISODE的績效(performance)
plt.axhline(y = 0, color='r', linestyle='-') # 加上0%報酬率的線(紅線)
plt.axhline(y = test_set_buy_and_hold_return, color='g', linestyle='-') # 加上B&H報酬率的線(綠線)
plt.show()

print("交易次數 vs rank")
plt.figure(2)
plt.plot(transaction_times_list_test) # X:第n個EPISODE Y:第n個EPISODE的total reward
plt.show()
# Out:
# 測試集：
# 報酬率 vs rank
# 交易次數 vs rank

# %% [markdown]
# ## 存測試集中表現較好的參數，作為下次訓練的起點(暫不採用)

# %%
# a = np.array(performance_list_test)
# best_param_index = np.argmax(a)
# print(best_param_index)

# # 儲存最好的1組參數
# torch.save(param_list50[best_param_index], 'last_best_param_as_start.pkl')
# # print(param_list50[best_param_index])
# print(sortPerformance50[best_param_index])

# %% [markdown]
# ## 畫出個股和台灣50的2014~2016收盤價趨勢圖

# %%
import matplotlib.ticker as ticker
x = pd.read_csv("D:\\專案\\資料集\\燦坤2430.csv", encoding='utf-8', index_col = '日期') # 路徑請自行修改

# %%
fig, ax = plt.subplots(figsize=(15,7))
plt.plot(x.loc["2014/1/2":"2018/12/28","收盤價"])
plt.rcParams['font.sans-serif'] = ['Noto Sans CJK TC']
plt.title("燦坤 2430 2014~2018 收盤價趨勢圖", fontsize=20)
xmajorLocator = ticker.MultipleLocator(50) # 每幾天顯示一次主要刻度
ax.xaxis.set_major_locator(xmajorLocator)
xminorLocator = ticker.MultipleLocator(10) # 每幾天顯示一次次要刻度
ax.xaxis.set_minor_locator(xminorLocator)
plt.axvline(x = '2015/1/5', color='r', linestyle=':')
plt.axvline(x = '2017/1/3', color='r', linestyle=':')
plt.axvline(x = '2017/3/31', color='r', linestyle=':')
plt.axvline(x = '2017/6/30', color='r', linestyle=':')
plt.xticks(rotation = 45)
plt.show()
# [2617:3353]

# %%
y = pd.read_csv("D:\\專案\\資料集\\twse0050_ver10.csv", index_col = '日期') # 路徑請自行修改

# %%
fig, ax = plt.subplots(figsize=(15,7))
plt.plot(y.loc["2014/1/2":"2016/12/30","收盤價"])
plt.rcParams['font.sans-serif'] = ['Noto Sans CJK TC']
plt.title("元大台灣50 0050 2014~2016 收盤價趨勢圖", fontsize=20)
xmajorLocator = ticker.MultipleLocator(50) # 每幾天顯示一次主要刻度
ax.xaxis.set_major_locator(xmajorLocator)
xminorLocator = ticker.MultipleLocator(10) # 每幾天顯示一次次要刻度
ax.xaxis.set_minor_locator(xminorLocator)
plt.xticks(rotation = 45)
plt.show()
# [2617:3353]

# %%
z = pd.read_csv("D:\\專案\\資料集\\東元1504.csv", index_col = '日期') # 路徑請自行修改

# %%
fig, ax = plt.subplots(figsize=(15,7))
plt.plot(z.loc["2014/1/2":"2018/12/28","收盤價"])
plt.rcParams['font.sans-serif'] = ['Noto Sans CJK TC']
plt.title("東元1504 2014~2018 收盤價趨勢圖", fontsize=20)
xmajorLocator = ticker.MultipleLocator(60) # 每幾天顯示一次主要刻度
ax.xaxis.set_major_locator(xmajorLocator)
xminorLocator = ticker.MultipleLocator(10) # 每幾天顯示一次次要刻度
ax.xaxis.set_minor_locator(xminorLocator)
plt.axvline(x = '2014/1/2', color='r', linestyle=':')
plt.axvline(x = '2016/1/4', color='r', linestyle=':')
plt.axvline(x = '2016/3/31', color='r', linestyle=':')
plt.axvline(x = '2016/6/30', color='r', linestyle=':')
plt.xticks(rotation = 45)
plt.show()
# [2617:3353]
